# %% [markdown]
#  In this file inputs and function used in application.py are defined.
#   The functions are dependent on the way how input dictionaries are specified.
#
#  If the limit of number of data downloads
#     are exceeded, please get a new API key from
#     http://inqubu.com/blog/index.php and change
#     it in functions getData and getDataWorld -
#     namely in the used url change api_key= .

# %%
import pandas as pd
import plotly.graph_objs as go
import pycountry
import requests
import json
import numpy as np

# %% [markdown]
# Creating dictionary with country name as key and its ISO 3166-1 Alpha-2 code
#     as value for each country (ex. {'Czechia':'cz'}). As these codes are needed to get
#     data from the API. The keys are displayed to the user and the values are used
#     in url to get the data.

# %%
countries = {}
for country in pycountry.countries:
    countries[country.name] = country.alpha_2.lower()

# %% [markdown]
#  Creating a dictionary of country characteristic from inqubu.
#     Where the keys are names/titles that are displayed to the user
#     in dropdown list and the values are the coresponding codes of the
#     variables in inqubu API.

# %%
characteristics_dict = {'BigMac Index': 'bigmac_index','The average number of birth per year per 1,000 population': 'birth_rate',
             'CO2 emissions (in metric tons per person per year)':'co2_emissions', 'Corruption index':'corruption_index',
            'Density':'density', 'Death rate': 'death_rate',
            'The total amount of government borrowings (unit: USD)':'debts',
            'Population':'population', 'The amount of government borrowings per person (unit: USD)':'debts_capita',
            'The percentage of government borrowings in relation to the GDP':'debts_percent',
            'Public expenditure on education (in % of the GDP for a country)':'education_expenditure',
            'The percentage of the land area covered by a forest for a country':'forest_area_percent',
            'Gross Domestic Product per person for a country (unit: USD)':'gdp_capita',
            'Happiness Index':'happiness_index','Public Expenditure on health ( % of the GDP)':'health_expenditure',
            'Life expectanty (years)':'life_expectancy','The amount of expenditures dedicated for tourism ( % of GDP)':'tourism_expenditure'}

# %%
def getData(characteristic,country):
    '''
        Function that is given code of a characteristic from inqubu
        and a country name. From the predefined list of countries it
        selects the corresponding code of the country (as a value
        corresponding to the key). Downloads the data from the given
        url into a json.
    '''
    url = 'http://inqstatsapi.inqubu.com?api_key=05305ba459195d25&countries='+countries.get(country)+'&data=' +characteristic+'&years=1990:2016'
    return requests.get(url).json()

# %%
getData('population','Slovakia')
# Out:
# [{'countryCode': 'sk',
#   'countryName': 'Slovakia',
#   'population': [{'year': '2016', 'data': '5428704'},
#    {'year': '2015', 'data': '5423801'},
#    {'year': '2014', 'data': '5418649'},
#    {'year': '2013', 'data': '5413393'},
#    {'year': '2012', 'data': '5407579'},
#    {'year': '2011', 'data': '5398384'},
#    {'year': '2010', 'data': '5391428'},
#    {'year': '2009', 'data': '5386406'},
#    {'year': '2008', 'data': '5379233'},
#    {'year': '2007', 'data': '5374622'},
#    {'year': '2006', 'data': '5373054'},
#    {'year': '2005', 'data': '5372807'},
#    {'year': '2004', 'data': '5372280'},
#    {'year': '2003', 'data': '5373374'},
#    {'year': '2002', 'data': '5376912'},
#    {'year': '2001', 'data': '5378867'},
#    {'year': '2000', 'data': '5388720'},
#    {'year': '1999', 'data': '5396020'},
#    {'year': '1998', 'data': '5390516'},
#    {'year': '1997', 'data': '5383291'},
#    {'year': '1996', 'data': '5373361'},
#    {'year': '1995', 'data': '5361999'},
#    {'year': '1994', 'data': '5346331'},
#    {'year': '1993', 'data': '5325305'},
#    {'year': '1992', 'data': '5305016'},
#    {'year': '1991', 'data': '5303294'},
#    {'year': '1990', 'data': '5299187'}]}]

# %%
def getDataWorld(charcteristics,year):
    '''
        For given inqbu characteristic code and year(as a string) returns the data
        for the whole world.
    '''
    url = 'http://inqstatsapi.inqubu.com?api_key=05305ba459195d25&cmd=getWorldData&data=' +charcteristics+'&year='+year
    return requests.get(url).json()

# %%
getDataWorld('population','2016')
# Out:
# [{'countryName': 'Afghanistan',
#   'countryCode': 'af',
#   'population': '34656032',
#   'year': '2016'},
#  {'countryName': 'Egypt',
#   'countryCode': 'eg',
#   'population': '95688681',
#   'year': '2016'},
#  {'countryName': 'Albania',
#   'countryCode': 'al',
#   'population': '2876101',
#   'year': '2016'},
#  {'countryName': 'Algeria',
#   'countryCode': 'dz',
#   'population': '40606052',
#   'year': '2016'},
#  {'countryName': 'Andorra',
#   'countryCode': 'ad',
#   'population': '77281',
#   'year': '2016'},
#  {'countryName': 'Angola',
#   'countryCode': 'ao',
#   'population': '28813463',
#   'year': '2016'},
#  {'countryName': 'Austria',
#   'countryCode': 'at',
#   'population': '8747358',
#   'year': '2016'},
#  {'countryName': 'Antigua and Barbuda',
#   'countryCode': 'ag',
#   'population': '100963',
#   'year': '2016'},
#  {'countryName': 'Equatorial Guinea',
#   'countryCode': 'gq',
#   'population': '1221490',
#   'year': '2016'},
#  {'countryName': 'Argentina',
#   'countryCode': 'ar',
#   'population': '43847430',
#   'year': '2016'},
#  {'countryName': 'Armenia',
#   'countryCode': 'am',
#   'population': '2924816',
#   'year': '2016'},
#  {'countryName': 'Azerbaijan',
#   'countryCode': 'az',
#   'population': '9762274',
#   'year': '2016'},
#  {'countryName': 'Ethiopia',
#   'countryCode': 'et',
#   'population': '102403196',
#   'year': '2016'},
#  {'countryName': 'Australia',
#   'countryCode': 'au',
#   'population': '24127159',
#   'year': '2016'},
#  {'countryName': 'Bahamas',
#   'countryCode': 'bs',
#   'population': '391232',
#   'year': '2016'},
#  {'countryName': 'Bahrain',
#   'countryCode': 'bh',
#   'population': '1425171',
#   'year': '2016'},
#  {'countryName': 'Bangladesh',
#   'countryCode': 'bd',
#   'population': '162951560',
#   'year': '2016'},
#  {'countryName': 'Barbados',
#   'countryCode': 'bb',
#   'population': '284996',
#   'year': '2016'},
#  {'countryName': 'Belgium',
#   'countryCode': 'be',
#   'population': '11348159',
#   'year': '2016'},
#  {'countryName': 'Belize',
#   'countryCode': 'bz',
#   'population': '366954',
#   'year': '2016'},
#  {'countryName': 'Benin',
#   'countryCode': 'bj',
#   'population': '10872298',
#   'year': '2016'},
#  {'countryName': 'Bhutan',
#   'countryCode': 'bt',
#   'population': '797765',
#   'year': '2016'},
#  {'countryName': 'Bolivia',
#   'countryCode': 'bo',
#   'population': '10887882',
#   'year': '2016'},
#  {'countryName': 'Bosnia and Herzegovina',
#   'countryCode': 'ba',
#   'population': '3516816',
#   'year': '2016'},
#  {'countryName': 'Botswana',
#   'countryCode': 'bw',
#   'population': '2250260',
#   'year': '2016'},
#  {'countryName': 'Brazil',
#   'countryCode': 'br',
#   'population': '207652865',
#   'year': '2016'},
#  {'countryName': 'Brunei',
#   'countryCode': 'bn',
#   'population': '423196',
#   'year': '2016'},
#  {'countryName': 'Bulgaria',
#   'countryCode': 'bg',
#   'population': '7127822',
#   'year': '2016'},
#  {'countryName': 'Burkina Faso',
#   'countryCode': 'bf',
#   'population': '18646433',
#   'year': '2016'},
#  {'countryName': 'Burundi',
#   'countryCode': 'bi',
#   'population': '10524117',
#   'year': '2016'},
#  {'countryName': 'Chile',
#   'countryCode': 'cl',
#   'population': '17909754',
#   'year': '2016'},
#  {'countryName': 'China',
#   'countryCode': 'cn',
#   'population': '1378665000',
#   'year': '2016'},
#  {'countryName': 'Costa Rica',
#   'countryCode': 'cr',
#   'population': '4857274',
#   'year': '2016'},
#  {'countryName': 'Denmark',
#   'countryCode': 'dk',
#   'population': '5731118',
#   'year': '2016'},
#  {'countryName': 'Germany',
#   'countryCode': 'de',
#   'population': '82667685',
#   'year': '2016'},
#  {'countryName': 'Dominica',
#   'countryCode': 'dm',
#   'population': '73543',
#   'year': '2016'},
#  {'countryName': 'Dominican Republic',
#   'countryCode': 'do',
#   'population': '10648791',
#   'year': '2016'},
#  {'countryName': 'Djibouti',
#   'countryCode': 'dj',
#   'population': '942333',
#   'year': '2016'},
#  {'countryName': 'Ecuador',
#   'countryCode': 'ec',
#   'population': '16385068',
#   'year': '2016'},
#  {'countryName': 'El Salvador',
#   'countryCode': 'sv',
#   'population': '6344722',
#   'year': '2016'},
#  {'countryName': 'Ivory Coast',
#   'countryCode': 'ci',
#   'population': '23695919',
#   'year': '2016'},
#  {'countryName': 'Estonia',
#   'countryCode': 'ee',
#   'population': '1316481',
#   'year': '2016'},
#  {'countryName': 'Fiji',
#   'countryCode': 'fj',
#   'population': '898760',
#   'year': '2016'},
#  {'countryName': 'Finland',
#   'countryCode': 'fi',
#   'population': '5495096',
#   'year': '2016'},
#  {'countryName': 'France',
#   'countryCode': 'fr',
#   'population': '66896109',
#   'year': '2016'},
#  {'countryName': 'Gabon',
#   'countryCode': 'ga',
#   'population': '1979786',
#   'year': '2016'},
#  {'countryName': 'Gambia',
#   'countryCode': 'gm',
#   'population': '2038501',
#   'year': '2016'},
#  {'countryName': 'Georgia',
#   'countryCode': 'ge',
#   'population': '3719300',
#   'year': '2016'},
#  {'countryName': 'Ghana',
#   'countryCode': 'gh',
#   'population': '28206728',
#   'year': '2016'},
#  {'countryName': 'Grenada',
#   'countryCode': 'gd',
#   'population': '107317',
#   'year': '2016'},
#  {'countryName': 'Greece',
#   'countryCode': 'gr',
#   'population': '10746740',
#   'year': '2016'},
#  {'countryName': 'United Kingdom',
#   'countryCode': 'gb',
#   'population': '65637239',
#   'year': '2016'},
#  {'countryName': 'Guatemala',
#   'countryCode': 'gt',
#   'population': '16582469',
#   'year': '2016'},
#  {'countryName': 'Guinea',
#   'countryCode': 'gn',
#   'population': '12395924',
#   'year': '2016'},
#  {'countryName': 'Guinea Bissau',
#   'countryCode': 'gw',
#   'population': '1815698',
#   'year': '2016'},
#  {'countryName': 'Guyana',
#   'countryCode': 'gy',
#   'population': '773303',
#   'year': '2016'},
#  {'countryName': 'Haiti',
#   'countryCode': 'ht',
#   'population': '10847334',
#   'year': '2016'},
#  {'countryName': 'Honduras',
#   'countryCode': 'hn',
#   'population': '9112867',
#   'year': '2016'},
#  {'countryName': 'India',
#   'countryCode': 'in',
#   'population': '1324171354',
#   'year': '2016'},
#  {'countryName': 'Indonesia',
#   'countryCode': 'id',
#   'population': '261115456',
#   'year': '2016'},
#  {'countryName': 'Iraq',
#   'countryCode': 'iq',
#   'population': '37202572',
#   'year': '2016'},
#  {'countryName': 'Iran',
#   'countryCode': 'ir',
#   'population': '80277428',
#   'year': '2016'},
#  {'countryName': 'Ireland',
#   'countryCode': 'ie',
#   'population': '4773095',
#   'year': '2016'},
#  {'countryName': 'Iceland',
#   'countryCode': 'is',
#   'population': '334252',
#   'year': '2016'},
#  {'countryName': 'Italy',
#   'countryCode': 'it',
#   'population': '60600590',
#   'year': '2016'},
#  {'countryName': 'Jamaica',
#   'countryCode': 'jm',
#   'population': '2881355',
#   'year': '2016'},
#  {'countryName': 'Japan',
#   'countryCode': 'jp',
#   'population': '126994511',
#   'year': '2016'},
#  {'countryName': 'Yemen',
#   'countryCode': 'ye',
#   'population': '27584213',
#   'year': '2016'},
#  {'countryName': 'Jordan',
#   'countryCode': 'jo',
#   'population': '9455802',
#   'year': '2016'},
#  {'countryName': 'Cambodia',
#   'countryCode': 'kh',
#   'population': '15762370',
#   'year': '2016'},
#  {'countryName': 'Cameroon',
#   'countryCode': 'cm',
#   'population': '23439189',
#   'year': '2016'},
#  {'countryName': 'Canada',
#   'countryCode': 'ca',
#   'population': '36286425',
#   'year': '2016'},
#  {'countryName': 'Cape Verde',
#   'countryCode': 'cv',
#   'population': '539560',
#   'year': '2016'},
#  {'countryName': 'Kazakhstan',
#   'countryCode': 'kz',
#   'population': '17797032',
#   'year': '2016'},
#  {'countryName': 'Qatar',
#   'countryCode': 'qa',
#   'population': '2569804',
#   'year': '2016'},
#  {'countryName': 'Kenya',
#   'countryCode': 'ke',
#   'population': '48461567',
#   'year': '2016'},
#  {'countryName': 'Kyrgyzstan',
#   'countryCode': 'kg',
#   'population': '6082700',
#   'year': '2016'},
#  {'countryName': 'Kiribati',
#   'countryCode': 'ki',
#   'population': '114395',
#   'year': '2016'},
#  {'countryName': 'Colombia',
#   'countryCode': 'co',
#   'population': '48653419',
#   'year': '2016'},
#  {'countryName': 'Comoros',
#   'countryCode': 'km',
#   'population': '795601',
#   'year': '2016'},
#  {'countryName': 'Democratic Republic of the Congo',
#   'countryCode': 'cd',
#   'population': '78736153',
#   'year': '2016'},
#  {'countryName': 'Republic of the Congo',
#   'countryCode': 'cg',
#   'population': '5125821',
#   'year': '2016'},
#  {'countryName': 'North Korea',
#   'countryCode': 'kp',
#   'population': '25368620',
#   'year': '2016'},
#  {'countryName': 'South Korea',
#   'countryCode': 'kr',
#   'population': '51245707',
#   'year': '2016'},
#  {'countryName': 'Kosovo',
#   'countryCode': 'xk',
#   'population': '1816200',
#   'year': '2016'},
#  {'countryName': 'Croatia',
#   'countryCode': 'hr',
#   'population': '4170600',
#   'year': '2016'},
#  {'countryName': 'Cuba',
#   'countryCode': 'cu',
#   'population': '11475982',
#   'year': '2016'},
#  {'countryName': 'Kuwait',
#   'countryCode': 'kw',
#   'population': '4052584',
#   'year': '2016'},
#  {'countryName': 'Lesotho',
#   'countryCode': 'ls',
#   'population': '2203821',
#   'year': '2016'},
#  {'countryName': 'Latvia',
#   'countryCode': 'lv',
#   'population': '1960424',
#   'year': '2016'},
#  {'countryName': 'Lebanon',
#   'countryCode': 'lb',
#   'population': '6006668',
#   'year': '2016'},
#  {'countryName': 'Liberia',
#   'countryCode': 'lr',
#   'population': '4613823',
#   'year': '2016'},
#  {'countryName': 'Libya',
#   'countryCode': 'ly',
#   'population': '6293253',
#   'year': '2016'},
#  {'countryName': 'Liechtenstein',
#   'countryCode': 'li',
#   'population': '37666',
#   'year': '2016'},
#  {'countryName': 'Lithuania',
#   'countryCode': 'lt',
#   'population': '2872298',
#   'year': '2016'},
#  {'countryName': 'Luxembourg',
#   'countryCode': 'lu',
#   'population': '582972',
#   'year': '2016'},
#  {'countryName': 'Madagascar',
#   'countryCode': 'mg',
#   'population': '24894551',
#   'year': '2016'},
#  {'countryName': 'Malawi',
#   'countryCode': 'mw',
#   'population': '18091575',
#   'year': '2016'},
#  {'countryName': 'Malaysia',
#   'countryCode': 'my',
#   'population': '31187265',
#   'year': '2016'},
#  {'countryName': 'Maldives',
#   'countryCode': 'mv',
#   'population': '417492',
#   'year': '2016'},
#  {'countryName': 'Mali',
#   'countryCode': 'ml',
#   'population': '17994837',
#   'year': '2016'},
#  {'countryName': 'Malta',
#   'countryCode': 'mt',
#   'population': '436947',
#   'year': '2016'},
#  {'countryName': 'Morocco',
#   'countryCode': 'ma',
#   'population': '35276786',
#   'year': '2016'},
#  {'countryName': 'Marshall Islands',
#   'countryCode': 'mh',
#   'population': '53066',
#   'year': '2016'},
#  {'countryName': 'Mauritania',
#   'countryCode': 'mr',
#   'population': '4301018',
#   'year': '2016'},
#  {'countryName': 'Mauritius',
#   'countryCode': 'mu',
#   'population': '1263473',
#   'year': '2016'},
#  {'countryName': 'Macedonia',
#   'countryCode': 'mk',
#   'population': '2081206',
#   'year': '2016'},
#  {'countryName': 'Mexico',
#   'countryCode': 'mx',
#   'population': '127540423',
#   'year': '2016'},
#  {'countryName': 'Micronesia',
#   'countryCode': 'fm',
#   'population': '104937',
#   'year': '2016'},
#  {'countryName': 'Moldova',
#   'countryCode': 'md',
#   'population': '3552000',
#   'year': '2016'},
#  {'countryName': 'Monaco',
#   'countryCode': 'mc',
#   'population': '38499',
#   'year': '2016'},
#  {'countryName': 'Mongolia',
#   'countryCode': 'mn',
#   'population': '3027398',
#   'year': '2016'},
#  {'countryName': 'Montenegro',
#   'countryCode': 'me',
#   'population': '622781',
#   'year': '2016'},
#  {'countryName': 'Mozambique',
#   'countryCode': 'mz',
#   'population': '28829476',
#   'year': '2016'},
#  {'countryName': 'Myanmar',
#   'countryCode': 'mm',
#   'population': '52885223',
#   'year': '2016'},
#  {'countryName': 'Namibia',
#   'countryCode': 'na',
#   'population': '2479713',
#   'year': '2016'},
#  {'countryName': 'Nepal',
#   'countryCode': 'np',
#   'population': '28982771',
#   'year': '2016'},
#  {'countryName': 'New Zealand',
#   'countryCode': 'nz',
#   'population': '4692700',
#   'year': '2016'},
#  {'countryName': 'Nicaragua',
#   'countryCode': 'ni',
#   'population': '6149928',
#   'year': '2016'},
#  {'countryName': 'Netherlands',
#   'countryCode': 'nl',
#   'population': '17018408',
#   'year': '2016'},
#  {'countryName': 'Niger',
#   'countryCode': 'ne',
#   'population': '20672987',
#   'year': '2016'},
#  {'countryName': 'Nigeria',
#   'countryCode': 'ng',
#   'population': '185989640',
#   'year': '2016'},
#  {'countryName': 'Norway',
#   'countryCode': 'no',
#   'population': '5232929',
#   'year': '2016'},
#  {'countryName': 'Oman',
#   'countryCode': 'om',
#   'population': '4424762',
#   'year': '2016'},
#  {'countryName': 'Pakistan',
#   'countryCode': 'pk',
#   'population': '193203476',
#   'year': '2016'},
#  {'countryName': 'Palau',
#   'countryCode': 'pw',
#   'population': '21503',
#   'year': '2016'},
#  {'countryName': 'Panama',
#   'countryCode': 'pa',
#   'population': '4034119',
#   'year': '2016'},
#  {'countryName': 'Papua New Guinea',
#   'countryCode': 'pg',
#   'population': '8084991',
#   'year': '2016'},
#  {'countryName': 'Paraguay',
#   'countryCode': 'py',
#   'population': '6725308',
#   'year': '2016'},
#  {'countryName': 'Peru',
#   'countryCode': 'pe',
#   'population': '31773839',
#   'year': '2016'},
#  {'countryName': 'Philippines',
#   'countryCode': 'ph',
#   'population': '103320222',
#   'year': '2016'},
#  {'countryName': 'Poland',
#   'countryCode': 'pl',
#   'population': '37948016',
#   'year': '2016'},
#  {'countryName': 'Portugal',
#   'countryCode': 'pt',
#   'population': '10324611',
#   'year': '2016'},
#  {'countryName': 'Puerto Rico',
#   'countryCode': 'pr',
#   'population': '3411307',
#   'year': '2016'},
#  {'countryName': 'Rwanda',
#   'countryCode': 'rw',
#   'population': '11917508',
#   'year': '2016'},
#  {'countryName': 'Romania',
#   'countryCode': 'ro',
#   'population': '19705301',
#   'year': '2016'},
#  {'countryName': 'Russia',
#   'countryCode': 'ru',
#   'population': '144342396',
#   'year': '2016'},
#  {'countryName': 'Solomon Islands',
#   'countryCode': 'sb',
#   'population': '599419',
#   'year': '2016'},
#  {'countryName': 'Zambia',
#   'countryCode': 'zm',
#   'population': '16591390',
#   'year': '2016'},
#  {'countryName': 'Samoa',
#   'countryCode': 'ws',
#   'population': '195125',
#   'year': '2016'},
#  {'countryName': 'San Marino',
#   'countryCode': 'sm',
#   'population': '33203',
#   'year': '2016'},
#  {'countryName': 'Sao Tome and Principe',
#   'countryCode': 'st',
#   'population': '199910',
#   'year': '2016'},
#  {'countryName': 'Saudi Arabia',
#   'countryCode': 'sa',
#   'population': '32275687',
#   'year': '2016'},
#  {'countryName': 'Sweden',
#   'countryCode': 'se',
#   'population': '9903122',
#   'year': '2016'},
#  {'countryName': 'Switzerland',
#   'countryCode': 'ch',
#   'population': '8372098',
#   'year': '2016'},
#  {'countryName': 'Senegal',
#   'countryCode': 'sn',
#   'population': '15411614',
#   'year': '2016'},
#  {'countryName': 'Serbia',
#   'countryCode': 'rs',
#   'population': '7057412',
#   'year': '2016'},
#  {'countryName': 'Seychelles',
#   'countryCode': 'sc',
#   'population': '94677',
#   'year': '2016'},
#  {'countryName': 'Sierra Leone',
#   'countryCode': 'sl',
#   'population': '7396190',
#   'year': '2016'},
#  {'countryName': 'Zimbabwe',
#   'countryCode': 'zw',
#   'population': '16150362',
#   'year': '2016'},
#  {'countryName': 'Singapore',
#   'countryCode': 'sg',
#   'population': '5607283',
#   'year': '2016'},
#  {'countryName': 'Slovakia',
#   'countryCode': 'sk',
#   'population': '5428704',
#   'year': '2016'},
#  {'countryName': 'Slovenia',
#   'countryCode': 'si',
#   'population': '2064845',
#   'year': '2016'},
#  {'countryName': 'Somalia',
#   'countryCode': 'so',
#   'population': '14317996',
#   'year': '2016'},
#  {'countryName': 'Spain',
#   'countryCode': 'es',
#   'population': '46443959',
#   'year': '2016'},
#  {'countryName': 'Sri Lanka',
#   'countryCode': 'lk',
#   'population': '21203000',
#   'year': '2016'},
#  {'countryName': 'St. Kitts and Nevis',
#   'countryCode': 'kn',
#   'population': '54821',
#   'year': '2016'},
#  {'countryName': 'St. Lucia',
#   'countryCode': 'lc',
#   'population': '178015',
#   'year': '2016'},
#  {'countryName': 'St. Vincent and the Grenadines',
#   'countryCode': 'vc',
#   'population': '109643',
#   'year': '2016'},
#  {'countryName': 'South Africa',
#   'countryCode': 'za',
#   'population': '55908865',
#   'year': '2016'},
#  {'countryName': 'Sudan',
#   'countryCode': 'sd',
#   'population': '39578828',
#   'year': '2016'},
#  {'countryName': 'South Sudan',
#   'countryCode': 'ss',
#   'population': '12230730',
#   'year': '2016'},
#  {'countryName': 'Suriname',
#   'countryCode': 'sr',
#   'population': '558368',
#   'year': '2016'},
#  {'countryName': 'Swaziland',
#   'countryCode': 'sz',
#   'population': '1343098',
#   'year': '2016'},
#  {'countryName': 'Syria',
#   'countryCode': 'sy',
#   'population': '18430453',
#   'year': '2016'},
#  {'countryName': 'Tajikistan',
#   'countryCode': 'tj',
#   'population': '8734951',
#   'year': '2016'},
#  {'countryName': 'Tanzania',
#   'countryCode': 'tz',
#   'population': '55572201',
#   'year': '2016'},
#  {'countryName': 'Thailand',
#   'countryCode': 'th',
#   'population': '68863514',
#   'year': '2016'},
#  {'countryName': 'East Timor',
#   'countryCode': 'tl',
#   'population': '1268671',
#   'year': '2016'},
#  {'countryName': 'Togo',
#   'countryCode': 'tg',
#   'population': '7606374',
#   'year': '2016'},
#  {'countryName': 'Tonga',
#   'countryCode': 'to',
#   'population': '107122',
#   'year': '2016'},
#  {'countryName': 'Trinidad and Tobago',
#   'countryCode': 'tt',
#   'population': '1364962',
#   'year': '2016'},
#  {'countryName': 'Chad',
#   'countryCode': 'td',
#   'population': '14452543',
#   'year': '2016'},
#  {'countryName': 'Czech Republic',
#   'countryCode': 'cz',
#   'population': '10561633',
#   'year': '2016'},
#  {'countryName': 'Tunisia',
#   'countryCode': 'tn',
#   'population': '11403248',
#   'year': '2016'},
#  {'countryName': 'Turkey',
#   'countryCode': 'tr',
#   'population': '79512426',
#   'year': '2016'},
#  {'countryName': 'Turkmenistan',
#   'countryCode': 'tm',
#   'population': '5662544',
#   'year': '2016'},
#  {'countryName': 'Tuvalu',
#   'countryCode': 'tv',
#   'population': '11097',
#   'year': '2016'},
#  {'countryName': 'Uganda',
#   'countryCode': 'ug',
#   'population': '41487965',
#   'year': '2016'},
#  {'countryName': 'Ukraine',
#   'countryCode': 'ua',
#   'population': '45004645',
#   'year': '2016'},
#  {'countryName': 'Hungary',
#   'countryCode': 'hu',
#   'population': '9817958',
#   'year': '2016'},
#  {'countryName': 'Uruguay',
#   'countryCode': 'uy',
#   'population': '45004645',
#   'year': '2016'},
#  {'countryName': 'Uzbekistan',
#   'countryCode': 'uz',
#   'population': '31848200',
#   'year': '2016'},
#  {'countryName': 'Vanuatu',
#   'countryCode': 'vu',
#   'population': '270402',
#   'year': '2016'},
#  {'countryName': 'Venezuela',
#   'countryCode': 've',
#   'population': '31568179',
#   'year': '2016'},
#  {'countryName': 'United Arab Emirates',
#   'countryCode': 'ae',
#   'population': '9269612',
#   'year': '2016'},
#  {'countryName': 'USA',
#   'countryCode': 'us',
#   'population': '323127513',
#   'year': '2016'},
#  {'countryName': 'Vietnam',
#   'countryCode': 'vn',
#   'population': '92701100',
#   'year': '2016'},
#  {'countryName': 'Belarus',
#   'countryCode': 'by',
#   'population': '9507120',
#   'year': '2016'},
#  {'countryName': 'Central African Republic',
#   'countryCode': 'cf',
#   'population': '4594621',
#   'year': '2016'},
#  {'countryName': 'Cyprus',
#   'countryCode': 'cy',
#   'population': '1170125',
#   'year': '2016'}]

# %% [markdown]
# Opening json of attractions/top places to visit in every country.
#     To see how the data was obtained please see scraper.py.
#     Then creating a dictionary where country names it the key
#     and the attractions are the corresponding value.

# %%
with open('Tripadvisor.json', 'r') as f:
        datastore = json.load(f)
datastore

attractions = {}
for country in datastore:
    attractions[country['country']]=country['attractions']

# %%
attractions
# Out:
# {'Aruba': [],
#  'Afghanistan': ['Shahr-e-Zahak (Red City)',
#   'Babur Gardens Mosque',
#   'Christian Cemetery',
#   'Bibi Mahroo Hill',
#   'Khwaja Abd Allah Ansari Shrine',
#   'Friday Mosque',
#   'Green Mosque',
#   'Band-e-Amir National Park',
#   'Abdul Rahman Khan Mosque',
#   'Gawhar Shad Madrasa and Mausoleum',
#   'National Museum of Afghanistan',
#   'Pul-e Kheshti Mosque',
#   'Bagram Airfield',
#   'Herat Citadel',
#   'Id Gah Mosque',
#   'Cultural Landscape and Archaeological Remains of the Bamiyan Valley',
#   'Red Mosque',
#   'Bagh-e Babur',
#   'Blue Mosque',
#   'Ziarat-e Sakhi',
#   'Kabul City Center',
#   'Shah-e Doh Shamshira Mosque',
#   'Darul Aman Palace',
#   'Kabul Museum',
#   'Qargha Lake',
#   'Buzkashi Stadium',
#   'Minaret and Archaeological Remains of Jam',
#   'Kabul National Stadium',
#   'Babur Tomb',
#   'Panjshir Mountains'],
#  'Angola': ['Cidade Alta',
#   'Igreja Metodista Unida De Bethel',
#   'Museu da Moeda',
#   'Avenida 4 de Fevereiro',
#   'National Anthropology Museum (Museu Nacional de Antropologia)',
#   'Ulengo Center',
#   'Museu Nacional da Escravatura',
#   'Igreja Nossa Senhora dos Remedios',
#   'Baia Dos Tigres',
#   'Kalandula Falls',
#   'Belas Shopping Mall',
#   'Parque Nacional do Quicama',
#   'Mausoleum of Agostinho Neto',
#   'Palacio de Ferro',
#   'Sangano Beach',
#   'Monumento do Soldado Desconhecido',
#   'Estacao Central de Luanda',
#   'Fortaleza de Sao Miguel',
#   'Igreja do Carmo',
#   'Ginga Shopping',
#   'Church of the Holy Family',
#   'Ilha do Mussulo',
#   'Miradouro da Lua',
#   'Se Catedral de Nossa Senhora de Fatima',
#   'Museum of Natural History',
#   'Praia Da Caotinha',
#   "Ship's Cemetery (Graveyard)",
#   'Se Catedral do Huambo',
#   'Tundavala',
#   'Black Rocks'],
#  'Anguilla': [],
#  'Åland Islands': [],
#  'Albania': [],
#  'Andorra': ['Centro Historico',
#   'Casa de la Vall',
#   'Parc Central',
#   'Cca - Centre Comercial Andorra',
#   '7 Poetes',
#   'La Noblesse du Temps',
#   'Madriu-Perafita-Claror Valley',
#   'Plaza del Poble',
#   'E.Leclerc Hiper',
#   'Casa de la Vall',
#   'Church of Sant Joan de Caselles',
#   'Grandvalira',
#   'Vallnord Pal-Arinsal',
#   'Engolasters Lake-Les Pardines Path',
#   'Soldeu - El Tarter',
#   'Andorra 2000 Centre Commercial',
#   'Pas De La Casa Ski',
#   'Sola Irrigation Canal Trail',
#   'Tobotronc',
#   'Museu del Tabac',
#   'Barri Antic',
#   "Rec de l'Obac",
#   'Rec del Sola',
#   'Museo de la Moto',
#   'Tristaina Lake Trail',
#   'Mirador del Roc del Quer',
#   'Puente de Paris',
#   'Sant Esteve Church',
#   'Estany de la Nou',
#   'Les Abelletes Lake Trail'],
#  'United Arab Emirates': ['Arabian Wildlife Center',
#   'Snoopy Island',
#   'Ajman Fishmarket',
#   'Hatta Hill Park',
#   'Ajman Museum',
#   'Burj Khalifa',
#   'Dubai Desert Conservation Reserve',
#   'Sheikh Zayed Grand Mosque Center',
#   'Jabal Jais',
#   'Al Ain Zoo',
#   'Grand Sheikh Zayed Mosque',
#   'Dubai Miracle Garden',
#   'The Dubai Fountain',
#   'Sharjah Aquarium',
#   'Jebel Hafeet',
#   'Al Montazah Parks',
#   'Sharjah Classic Car Museum',
#   'Al Noor Mosque',
#   'Al Majaz Waterfront',
#   'Sharjah Museum of Islamic Civilization',
#   'Hatta Mountain Bike Trail Centre',
#   'Louvre Abu Dhabi',
#   'Global Village',
#   'Al Bidya Mosque',
#   'Ajman Beach',
#   'Fujairah Historic Fort',
#   'Buhaira Corniche',
#   'Mleiha Archaeological Centre',
#   'Al Hayl Castle',
#   'The Dubai Mall'],
#  'Argentina': ['Museo de arte Tigre',
#   'Parque Nacional Tierra del Fuego',
#   'Parque Nacional Los Glaciares',
#   'MAAM - Museo de Arqueologia de Alta Montana de Salta',
#   'Garganta del Diablo',
#   'Canal Beagle',
#   'Anfiteatro Natural',
#   'Camino de las Altas Cumbres',
#   'Complejo Aerosilla Carlos Paz',
#   'Puerto de Frutos',
#   'Circuito Chico',
#   'Cuesta del Obispo',
#   'Virgen de los Tres Cerritos',
#   'Monumento Historico Nacional a la Bandera',
#   'Camino de las Las 100 Curvas',
#   'Laguna Esmeralda',
#   'La Isla de los Inventos',
#   'Torre Tanque',
#   'Estancia El Ombu de Areco',
#   'Route of the Seven Lakes',
#   'Canon del Atuel',
#   'Iglesia de Los Capuchinos',
#   'Peninsula Valdes',
#   'Parque Provincial Aconcagua',
#   'Salinas Grandes',
#   'Museo de La Plata',
#   'Parque Nahuelito',
#   'Cerro Tronador',
#   'Teatro Colon',
#   'El Cerro de la Cruz'],
#  'Armenia': [],
#  'American Samoa': ['Cloud Rainforest to Reef Hike',
#   'Mount Alava',
#   'National Park of American Samoa',
#   'Ofu Beach',
#   'Matafao Peak',
#   'Blunts Point Trail',
#   'National Park of American Samoa Visitor Center',
#   'Two Dollar Beach',
#   'Tauese P.F. Sunia Ocean Center (National Marine Sanctuary of American Samoa)',
#   'Pala Lake',
#   "Ma'ama'a Cove",
#   'Fagatele Bay Trail',
#   'National Park of American Samoa Breakers Point Trail',
#   'World War II Heritage Trail',
#   'Lower Sauma Ridge Hike',
#   'Congregational Christian Church',
#   'National Marine Sanctuary of American Samoa',
#   'Jean P. Haydon Museum'],
#  'Antarctica': [],
#  'French Southern Territories': ['Place des Palmistes',
#   'Office du tourisme de Saint-Laurent du Maroni',
#   'Domaine Pascaud',
#   'Fort Trio',
#   'Kourou Space Centre (Guiana Space Centre)',
#   'Marshes of Caw',
#   'Maroni (Marowijne) River',
#   'Royal Ranch',
#   'Fort Ceperou',
#   'La Montagne des Singes',
#   'Remire-Montjoly Beach',
#   'Musee Departmental Alexandre-Franconie',
#   'Plage des Hattes',
#   'Ilet la Mere',
#   'Eglise Saint-Dominique de Roura',
#   'Jardin Botanique',
#   'Sentier des Salines',
#   'Association Chou Ai',
#   'Le bagne des Annamites',
#   'Jardin Botanique de Guyane',
#   'Camp De La Transportation',
#   'Zoo de Guyane',
#   'Sentier du Rorota',
#   'Crique Canceler',
#   'Crique Toussaint',
#   'St. Sauveur Cathedral',
#   "Devil's Island",
#   'Brasserie Guyanaise',
#   "Centre d'Archeologie Amerindienne de Kourou",
#   'Cacao Village'],
#  'Antigua and Barbuda': [],
#  'Australia': ['Australian War Memorial',
#   'Mount Wellington',
#   'Koala Hospital',
#   'RFDS Darwin Tourist Facility',
#   'Fraser Island',
#   'Lighthouse Trail',
#   'Maria Island National Park',
#   'Swan River',
#   'Cairns Botanic Gardens',
#   'Cairns Esplanade Lagoon',
#   'Lake McKenzie',
#   'Castle Hill',
#   'Blue Mountains',
#   'Cataract Gorge Reserve',
#   'Adelaide Botanic Garden',
#   'Royal Botanic Gardens Victoria',
#   'Newcastle Memorial Walk',
#   'National Anzac Centre',
#   'Sydney Opera House',
#   'Kings Park and Botanic Garden',
#   'The Strand',
#   'Melbourne Cricket Ground (MCG)',
#   'South Bank Parklands',
#   'Turquoise Bay',
#   'Uluru',
#   'Ivanhoe Wines',
#   "Muddy's Playground",
#   'CityCat Ferry',
#   'Noosa National Park',
#   'Cable Beach'],
#  'Austria': ['Postlingbergbahn',
#   'Historic Center of Vienna',
#   'Gipfelwelt 3000',
#   'Red Bull Hangar-7',
#   'Salzburger Altstadt',
#   'Untersberg',
#   'Old Town',
#   'Hallstatt Skywalk "Welterbeblick"',
#   'Designer Outlet Parndorf',
#   'Schmittenhohe',
#   'Tiergarten Schoenbrunn - Zoo Vienna',
#   'Bregenz Festival',
#   'Nockalmstrasse',
#   'Zell Am See',
#   'Schloss Eggenberg',
#   'Kunsthistorisches Museum Wien',
#   'Lake Worthersee',
#   'Schlossberg',
#   'Albertina',
#   'Villach Alpine Road',
#   'Schonbrunn Palace',
#   'Schwarzsee',
#   'Schloss Hellbrunn',
#   'Imperial Palace (Hofburg)',
#   'Fortress Hohensalzburg',
#   'Grossglockner',
#   'Salzwelten',
#   'Altstadt von Graz',
#   'Innsbrucker Nordkettenbahnen',
#   'Lake Attersee'],
#  'Azerbaijan': [],
#  'Burundi': ['Karera Waterfalls',
#   'Livingstone-Stanley Monument',
#   'Eglise Vivante de Jesus Christ',
#   'So Beautiful',
#   'Reptile Park (Parc des Reptiles)',
#   'TwoFiveSeven Arts',
#   'Geological Museum of Burundi',
#   'Musee Vivant',
#   'Regina Mundi Cathedral',
#   'Augustine Tours Ltd',
#   'Come and See Burundi',
#   "Monument de l'Unite",
#   'Parc National de la Ruvubu',
#   'National Museum of Gitega',
#   'Mausolee du Prince Louis Rwagasore',
#   'Gishora Drum Sanctuary',
#   'Rusizi National Park'],
#  'Belgium': ['Gravensteen',
#   'Botanical Garden Kruidtuin',
#   "St. Bavo's Cathedral (Sint-Baafskathedraal)",
#   'Le Bois du Cazier',
#   'Grand Place',
#   'Montagne de Bueren',
#   'Domaine de Berinzenne',
#   'Graslei and Korenlei',
#   'Ghent City Center',
#   'Old Town of Durbuy',
#   'Groot Begijnhof',
#   'De Halve Maan Brewery',
#   'La Citadelle de Dinant',
#   'The Markt',
#   'ZOO Planckendael',
#   'Gallo-Romeins Museum',
#   'Antwerpen-Centraal',
#   'Historic Centre of Brugge',
#   'Citadelle (Citadel)',
#   'Town Hall (Stadhuis)',
#   'Pairi Daiza',
#   'Huisje van Majutte',
#   'Belfort',
#   'Atlantic Wall Museum',
#   'Menin Gate Memorial',
#   'Last Post ceremony',
#   'Bastogne War Museum',
#   '\nGraspop Metal Festival\n',
#   'Francois Duesberg Museum',
#   'Abdijsite Herkenrode',
#   'Japanese Tuin'],
#  'Benin': ['Musee de la Fondation Zinsou',
#   'Etoile Rouge',
#   'Marche Dantokpa',
#   'Village Artisanal',
#   'Musee Honme (Palais Royal)',
#   'Fidjrosse Beach',
#   'Villa Karo',
#   'Place des Martyrs',
#   'Lac Nokoue',
#   'Royal Palaces of Abomey',
#   'Pendjari National Park',
#   'Obama Beach',
#   'La Porte Du Non Retour',
#   'Artisanal Center',
#   "Palais des rois d'Abomey",
#   'Great Mosque of Porto-Novo',
#   'Fondation Zinsou',
#   'Jardin Place Jean Bayol',
#   'Saint Michel church',
#   "Cathedrale Notre Dame de l'Immaculee Conception",
#   'Palais des Congres',
#   'Ethnographique Museum of Porto Novo',
#   'Ouidah Museum of History',
#   'Temple des Pythons',
#   'da Silva Museum',
#   'Marche Missebo',
#   'Grande Mosquee de Zongo',
#   'Cotonou Cathedral',
#   'Bienvenue au Benin',
#   "Stade de l'Amitie"],
#  'Bonaire, Sint Eustatius and Saba': [],
#  'Burkina Faso': ['Reserve de Nazinga',
#   'The Ruins of Loropeni',
#   'Ouagadougou Markets',
#   'BIblioteca OLVIDO',
#   'Eglise de Dapoya',
#   'Mosque of Bobo-Dioulasso',
#   "Musee d'Issouka",
#   'FasoParc',
#   'Quartier Mosque',
#   'Cathedral of Ouagadougou',
#   'Domes de Fabedougou',
#   'Mare aux Hippopotames',
#   'Marche aux Bestiaux',
#   'Karfiguela Falls',
#   'Parc Animalier',
#   'Les Pics de Sindou',
#   'Laongo Sculpture Symposium',
#   'The Grand Mosque at Bani',
#   'marche de Sankariare',
#   'statue of Sembene Ousmane',
#   'Les Cascades de Banfora',
#   'Royal Palace of Tiebele',
#   'Musee De La Bendrologie de Manega',
#   'Grande Mosquee de Ouagadougou',
#   'Parc Urbain Bangr-Weoogo',
#   'Cathedrale Notre Dame de Lourdes'],
#  'Bangladesh': ['Boga Lake',
#   'Bangladesh National Museum',
#   'Nilachal',
#   'Jaflong',
#   'Bangabandhu Safari Park',
#   'Inani Beach',
#   'Lalbag Fort',
#   'Ahsan Manzil',
#   'Ratargul Swamp Forest',
#   'National Parliament House',
#   'Naval Beach',
#   'Sadarghat',
#   'Nilgiri Mountains',
#   "Cox's Bazar Beach",
#   'Bisnakandi',
#   'Bangabandhu Memorial Museum',
#   'Saint Martin Island',
#   'Richhang Falls',
#   'Dhakeshwari Temple',
#   'Chittagong Commonwealth War Cemetery',
#   'Shahid Minar',
#   'Nuhash Polli',
#   'Bangabandhu Sheikh Mujibur Rahman Novo Theatre',
#   'New Market',
#   'Bhawal National Park',
#   'Liberation War Museum',
#   'Sonakanda Fort',
#   'Hatirjheel',
#   'Sonargaon',
#   'Zinda park'],
#  'Bulgaria': ['Kiwi Market',
#   'Method Snow School',
#   'Cathedral of the Assumption of the Virgin',
#   'Ski Bansko',
#   'Sea Garden',
#   'The Retro Museum In Varna',
#   'Aquapolis',
#   'St. Alexander Nevski Cathedral',
#   'Stone Forest',
#   'Vitosha Boulevard',
#   'Sozopol Old Town',
#   'Sea Garden',
#   'Vitosha Mountain',
#   'Plovdiv Old Town',
#   'Borovets Ski Resort',
#   'Pobiti Kamani',
#   'Varna Archaeological Museum',
#   'Action Aquapark',
#   'Nirvana Beach',
#   'Hotel International Casino',
#   'Holy Trinity Church',
#   'Old Nessebar',
#   'Tsarevets',
#   'Vihren',
#   'Pirin Street',
#   'Boyana Church',
#   'Aladzha Monastery',
#   'Rila Monastery',
#   'Bansko Ski Mania',
#   'Saint Nikolas Russian Church (Tsurkva Sveta Nikolai)'],
#  'Bahrain': ['Al Dar Islands',
#   'The Lagoon Park',
#   'Shri Krishna Temple Bahrain',
#   'Gold City',
#   'Lost Paradise of Dilmun Water Park',
#   'Bahrain National Museum',
#   'Bab el-Bahrain Souk',
#   'Wahooo! Waterpark',
#   'Tree Of Life',
#   'Mukta A2 Cinemas',
#   'Reef Island',
#   'The Bahrain Mall',
#   "Beit Al Qur'an",
#   "Qal'at al-Bahrain",
#   'National Theatre of Bahrain',
#   'Seef Mall - Seef District',
#   'Prince Khalifa Bin Salman Park',
#   'Ahmed Al Fateh Islamic Center',
#   'Adhari Park',
#   'Moda Mall - Bahrain World Trade Center',
#   'Seef Mall - Muharraq',
#   'Shaikh Isa bin Ali House',
#   'Bahrain International Circuit',
#   'Bahrain Financial Harbour',
#   'Royal Camel Farm',
#   'The Avenues',
#   'King Fahd Causeway',
#   'Al-Fatih Mosque (Great Mosque)',
#   'Al Azizia Birds Kingdom',
#   'Dragon City Bahrain'],
#  'Bahamas': [],
#  'Bosnia and Herzegovina': ['Hercegovacka Gracanica',
#   'Kravice Falls',
#   'Trg Slobode',
#   'Sarajevo War Tunnel',
#   'Galerija 11/07/95',
#   'Holy Apostles Peter and Paul Orthodox Church',
#   'Slana Banja',
#   'War Childhood Museum',
#   'Museum Of Crimes Against Humanity And Genocide 1992-1995',
#   'Cathedral of Christ the Saviour, Banja Luka',
#   'Underground Labyrinth Ravne',
#   'Sarajevo Olympic Bobsleigh and Luge Track',
#   'Neretva Delta Valley',
#   'Bosnian Pyramid',
#   'Apparition Hill',
#   'Ferhadija Mosque',
#   'Gazi Husrev-beg Mosque',
#   'Park Ravne 2',
#   'Vrbas River',
#   'Krupa Water Falls',
#   'Una National Park',
#   'Vrelo Bosne',
#   "ARK D-0: Tito's Nuclear Bunker",
#   'Tvrdos Monastery',
#   'Sarajevo City Hall',
#   'Old Bridge (Stari Most)',
#   'Bascarsija',
#   'Old Bridge Area of the Old City of Mostar',
#   'Neretva River',
#   'il Monte Della Croce'],
#  'Saint Barthélemy': [],
#  'Belarus': ['Saint Euphrosyne Monastery',
#   'Gomel Palace & Park Ensemble',
#   'The Jesuit Catholic Church',
#   'Nesvizh Castle',
#   'National Library of Belarus',
#   'The National Art Museum of the Republic of Belarus',
#   'Minskiy Komarovskiy Market',
#   'Upper City',
#   "Zhiliber's Park",
#   'Minsk-Arena Complex',
#   'Kalozha Church Boris-Gleb Church',
#   'Belarusian State Museum of the History of the Great Patriotic War',
#   'Memorial Complex Brest Hero-Fortress',
#   'National Opera and Ballet Theatre of Belarus',
#   'Island of Tears',
#   'Marc Chagall Home',
#   'Mogilev City Hall',
#   'Sovetskaya Street',
#   'Church of Saints Simon and Helena',
#   'Monument to Fallen Jewish People on March 2, 1942',
#   'Minsk Zoo',
#   'Victory Park',
#   'Svislach River Embankment',
#   'Victory Square',
#   'Central Botanical Garden of the National Academy of Sciences of Belarus',
#   'Lake Narach',
#   'Museum Strana Mini',
#   'Loshitskiy Park',
#   'Belarusian Folk Museum of Architecture and Rural Life',
#   'Uspensky Cathedral'],
#  'Belize': ['Secret Beach',
#   "St John's Cathedral",
#   'Actun Tunichil Muknal',
#   'Ocean Ferry Belize',
#   'Billy Barquiedier National Park',
#   'Bannister Island',
#   'Old Belize Cultural and Historical Center',
#   'Baron Bliss Lighthouse',
#   'Altun Ha & The Olde Belize River',
#   'San Pedro Belize Express Water Taxi Ltd.',
#   'Cahal Pech Mayan Ruins & Museum',
#   'Ambergris Museum & Cultural Center',
#   'The Belize Sign Monument',
#   "Nohoch Che'en Caves Branch Archaeological Reserve",
#   'Green Iguana Conservation Project',
#   'Caye Caulker Water Taxi',
#   'Hol Chan Marine Reserve',
#   'Bunches of Fun Banana Farm Tours',
#   "Glover's Reef Marine Reserve",
#   'Caye Caulker',
#   'Belize Tourism Village',
#   'Shark Ray Alley',
#   'Belizean Arts',
#   'Cucumber Beach',
#   'Xunantunich',
#   'Bacalar Chico National Park and Marine Reserve',
#   'Swing Bridge',
#   'Museum of Belize',
#   'Mexico Rocks',
#   'Laughing Bird Caye National Park'],
#  'Bermuda': [],
#  'Bolivia, Plurinational State of': ['Church of San Felipe Neri (Oratorio de San Felipe de Neri)',
#   'Museum of Indigenous Art ASUR',
#   'Ventura mall',
#   "Dinosaur Tracks (Cal Orck'o)",
#   'Guembe',
#   'Tunari Peak',
#   'Plaza 14 de Septiembre',
#   'WMDR Yungas Road',
#   'Salar de Uyuni',
#   'Comunidad Inti Wara Yassi',
#   'Mi Teleferico',
#   'Isla Incahuasi',
#   'Isla del Sol',
#   'El Cristo de la Concordia',
#   'Museo del Tesoro',
#   'Cerro Rico',
#   'Samaipata',
#   'Plaza 25 de Mayo',
#   'Palacio Portales',
#   'Laguna Angostura',
#   'Parque de la Familia',
#   'Jardin de las Delicias',
#   'Aguas Danzantes',
#   'La Cancha',
#   'Puerta del Diablo',
#   'Laguna Colorada',
#   'House of Liberty Museum - Casa de la Libertad',
#   'Lake Titicaca',
#   'Plaza 24 de Septiembre',
#   'La Recoleta'],
#  'Brazil': ['Pontao do Lago Sul',
#   'Teatro Amazonas',
#   'Orla de Atalaia',
#   'Baia do Sancho',
#   'Instituto Ricardo Brennand',
#   'Iguazu Falls',
#   'Museu de Ciencias e Tecnologia da PUCRS',
#   'Jardim Botanico de Curitiba',
#   'Parque Unipraias Camboriu',
#   'Muro Alto Beach',
#   'Imperial Museum',
#   'Coffee Museum',
#   'Estacao das Docas',
#   'Parque Estadual do Caracol',
#   'Black Lake',
#   'Vale dos Vinhedos',
#   'Arena do Gremio',
#   'Amantikir Park',
#   'Mercado Central de Belo Horizonte',
#   'Morro do Macaco',
#   'Prainhas do Pontal do Atalaia',
#   'Rua das Pedras',
#   'Santo Antonio de Lisboa',
#   'Mangal das Garcas',
#   'Dunas de Genipabu',
#   'Cataguas Island',
#   'Casa Valduga Winery',
#   'Pao de Acucar',
#   'Mini Mundo',
#   'Parque Ibirapuera'],
#  'Barbados': [],
#  'Brunei Darussalam': ['Silver Jubilee Park',
#   'Temburong River',
#   'Sultan Omar Ali Saifuddin Mosque',
#   'The Longhouse of Teraja',
#   'Menara Cendera Kenangan',
#   'Pulau Berambang',
#   'Lumut Beach',
#   'Gadong Night Market',
#   'Jerudong Park',
#   'Royal Regalia Museum',
#   'Rimba Garden Central (RGC)',
#   'Istana Nurul Iman',
#   'Oil & Gas Discovery Centre',
#   'Seria Mosque',
#   'Tasek Lama Recreational Park',
#   'Kampong Ayer - Venice of East',
#   "Jame'Asr Hassanil Bolkiah Mosque",
#   'Liang Lumut Recreation Club',
#   'Pantai Seri Kenangan',
#   'Ulu Temburong National Park',
#   'Masjid kampong Pandan',
#   'Masjid Muhammad Jamalul Alam Mosque',
#   'Teraja Waterfall',
#   'Billionth Barrel Monument',
#   'Bukit Patoi Forest Recreation Park',
#   'BJ Archery Sport Centre',
#   'Pelumpong Spit',
#   'Tasek Merimbun Heritage Park',
#   'Tamu Kianggeh',
#   'Jerudong Park Playground'],
#  'Bhutan': ['Tango Buddhist Institute',
#   'National Institute for Zorig Chusum',
#   'Khamsum Yulley Namgyal Chorten',
#   'Paro River',
#   'Rinpung Dzong',
#   'Kyichu Lhakhang',
#   'Simtokha Dzong',
#   'Chele La Pass',
#   'Royal Textile Academy of Bhutan',
#   'Kurje Lhakhang',
#   'Thimphu Chorten (Memorial Chorten)',
#   'National Museum',
#   'Paro Taktsang (Tiger’s Nest)',
#   'Tachogang Lhakhang Bridge',
#   'Choki Traditional Art School',
#   'Haa Valley',
#   'Simply Bhutan Museum',
#   'The Royal Manas National Park',
#   'Punakha Dzong',
#   'Dzongdrakha Temple',
#   'Tashichho Dzong (Thimpu Dzong)',
#   'Phobjikha Valley',
#   'Changangkha Lhakhang',
#   'Buddha Dordenma',
#   'Dochula Pass',
#   'Bhutan Gate',
#   'Motithang Takin Preserve',
#   'Bhutan Post Office Headquarters',
#   'Punakha Suspension Bridge',
#   'National Folk Heritage Museum'],
#  'Bouvet Island': ['Volunteer Point',
#   'Mount Usborne',
#   'Falkland Islands Museum',
#   'Christ Church Cathedral',
#   'Mount Maria',
#   'Kelp Point',
#   'Cape Bougainville',
#   'Battle Memorial',
#   'Surf Bay',
#   'Bluff Cove Lagoon',
#   'New Island Conservation Trust',
#   '1982 Liberation Memorial',
#   'Museum Britannia House',
#   'Cape Pembroke Lighthouse',
#   'Argentine Military Cemetery',
#   'Sea Lion Island',
#   "Devil's Nose",
#   'St. Mary s Catholic Church',
#   'Weddell Island',
#   'Bleaker Island',
#   'Saunders Island',
#   'Blue Beach Military Cemetery',
#   'Mount Longdon',
#   'Elephant Beach Farm',
#   'Pebble Island',
#   'Lady Elizabeth Shipwreck',
#   'Gypsy Cove',
#   'Carcass Island',
#   "Bertha's Beach",
#   'Whalebone Arch'],
#  'Botswana': ['Gaborone Game Reserve',
#   'National Museum',
#   'National Assembly Building',
#   'Gaborone Sun',
#   'Sebele Centre',
#   'InPlay',
#   'Khutse Game Reserve',
#   'Mokolodi Nature Reserve',
#   'CARACAL Biodiversity Center',
#   'Chobe National Park',
#   'Bahurutshe Cultural Village',
#   'Christ the King Cathedral',
#   'Airport Junction',
#   'Moremi Gorge',
#   'ISKCON Gaborone (Krishna Balaram Palace)',
#   'Trinity Church',
#   'Gaborone Dam',
#   'Lion Park Resort',
#   "Matsieng's Footprints",
#   'Savute Reserve',
#   'Okavango River',
#   'Makgadikgadi Salt Pan',
#   'Moremi Game Reserve',
#   'Riverwalk Mall',
#   'ISKCON Gaborone',
#   'Moremi Wildlife Reserve',
#   'Okavango Delta',
#   'Sri Balaji Temple',
#   'Kubu Island',
#   "Three Chiefs' Statues"],
#  'Central African Republic': ['Les Chutes de Boali (Boali Waterfalls)',
#   'Bamingui-Bangoran National Park',
#   'Dzanga-Sangha Reserve',
#   'Notre-Dame of Bangui Cathedral',
#   'Place de la Republique',
#   'Marche Central (Central Market)',
#   'The Big Mosque',
#   'Manovo-Gounda St Floris National Park',
#   'Musee de Boganda (Boganda Museum)',
#   "Melanie's Beauty",
#   'Oubangui River',
#   'K-Cinq (Km-5 Intersection)'],
#  'Canada': ['Heritage Park Historical Village',
#   'Canadian War Museum',
#   'Canadian Museum for Human Rights',
#   'Signal Hill',
#   'Icefields Parkway',
#   'Stanley Park',
#   'Windsor Riverfront',
#   'Whistler Blackcomb',
#   'Lynn Canyon Park',
#   'Peller Estates Winery',
#   'Myra Canyon Park',
#   'Old Quebec',
#   'Parliament Hill and Buildings',
#   'Springbank Park',
#   'Port Credit',
#   'Toronto Island Park',
#   'Kinsol Trestle',
#   'Halifax Public Gardens',
#   'Niagara Falls',
#   'Athabasca Falls',
#   'Royal BC Museum',
#   '\nRoyal Nova Scotia International Tattoo\n',
#   'Moraine Lake',
#   'Fort Edmonton Park',
#   'The Grotto',
#   'Canmore Cave Tours',
#   'Pacific Rim National Park',
#   'Banff Gondola',
#   'Maligne Lake',
#   'Notre-Dame Basilica',
#   "Ripley's Aquarium Of Canada"],
#  'Cocos (Keeling) Islands': [],
#  'Switzerland': ['Old Town',
#   'Rheinfahre',
#   'Harder Kulm',
#   'Lake Geneva',
#   'Stiftsbibliothek',
#   'Falconeria Locarno',
#   'Galleria Baumgartner',
#   'Basel Minster',
#   'Lake Lugano',
#   'Altstadt-Spaziergange durch Basel',
#   'Basel Paper Mill Museum',
#   'Mount Titlis',
#   'Queen Studio Experience',
#   'Old City',
#   'Diavolezza',
#   'Trummelbach Falls',
#   'Rochers-de-Naye',
#   'Mount Pilatus',
#   'The Matterhorn',
#   'GoldenPass Line',
#   'Kathedrale St.Gallen',
#   'The Olympic Museum Lausanne (Musee Olympique)',
#   'Jungfraujoch',
#   'Zoo Basel',
#   'Kunstmuseum Basel',
#   'Freddie Mercury Statue',
#   'Fox Town Factory Stores',
#   'Lake Zurich',
#   'Bernina Express',
#   'Grindelwald-First'],
#  'Chile': ['Isla Magdalena',
#   'Valle del Elqui',
#   'Paseo Gervasoni',
#   'Parque Oncol',
#   'Universidad de Concepcion',
#   'Reserva Nacional Rio Los Cipreses',
#   'La Sebastiana',
#   'Anakena Beach',
#   'San Cristobal Hill',
#   'Jardin Botanico Nacional',
#   'Volcan Osorno',
#   'Parque Ecuador',
#   'Glacier Grey',
#   'Lemuy Island',
#   'Geyser del Tatio',
#   'Oficina Salitrera Santiago Humberstone',
#   'Jardin Botanico de la Universidad Austral de Chile',
#   'Parque del Estrecho de Magallanes',
#   'Bahia de Corral',
#   'Cementerio Municipal',
#   'Playa Renaca',
#   'Valle De La Luna',
#   'Termas Geometricas',
#   'Saltos del Petrohue',
#   'Nao Victoria Museo',
#   'Casa del Arte - Pinacoteca',
#   'Cerro Concepcion',
#   'Embalse El Yeso',
#   'Sky Costanera',
#   'Cuevas de Anzota'],
#  'China': ['Qingdao Beer Museum',
#   'Zhangjiajie National Forest Park',
#   'COCO Park',
#   'Harbin Ice and Snow World',
#   'Chimelong Safari Park',
#   'Hubei Provincial Museum',
#   'The Bund (Wai Tan)',
#   'Yalong Bay',
#   'Macau Tower Convention & Entertainment Centre',
#   'Gulangyu Island',
#   "Humble Administrator's Garden",
#   'The Museum of Qin Terra-cotta Warriors and Horses',
#   'Tian Tan Buddha (Big Buddha)',
#   'Giant Panda Breeding Research Base (Xiongmao Jidi)',
#   'Laoshan Scenic Area',
#   'Shenzhen Window of the World',
#   'Casino at Venetian Macao',
#   'Chimelong Ocean Kingdom',
#   'The Memorial of the Nanjing Massacre',
#   'Reed Flute Cave (Ludi Yan)',
#   "Ruins of St. Paul's",
#   'Mutianyu Great Wall',
#   'Nanshan Temple',
#   'Macau Giant Panda Pavilion',
#   'Lantau island',
#   'Shenzhen Lianhuashan Park',
#   'West Lake (Xi Hu)',
#   'Historic Centre of Macau',
#   'China Folk Culture Village',
#   'Three Gorges'],
#  "Côte d'Ivoire": [],
#  'Cameroon': ['Musee Ethnographique des Peuples de la Foret',
#   'Mankon Museum',
#   'Limbe Wildlife Centre',
#   'New Bell Mosque',
#   'Bois Sainte Anastasie',
#   'Mount Cameroon',
#   'Le Monument aux Morts',
#   'National Museum of Yaounde (Le Musee National de Yaounde)',
#   'Musee Maritime de Douala',
#   'Bimbia',
#   'Blackitude Museum',
#   'Caves Akok Bekoe',
#   'Marche des Fleurs',
#   'Londji village des pecheurs',
#   'Club Market VIP Lounge',
#   "Campo Ma'an National Park",
#   'Marche Artisanal de Douala',
#   "Doual'Art",
#   'La Nouvelle Liberte',
#   'Monument de la Reunification',
#   'Mefou National Park',
#   'Cathedrale Saint-Pierre-et-Saint-Paul',
#   'cathedrale de la paix, North 10, Yaunde, Camerun',
#   'Ecopark',
#   'Musee Provincial de Douala',
#   'Chutes de la Lobe',
#   "Fon's Palace",
#   'Benedictine Museum of Mont-Febe',
#   'Bamenda Ring Road',
#   'Foumban Royal Palace & Museum'],
#  'Congo, The Democratic Republic of the': ['Parc de la Vallee de la Nsele',
#   'Bombo Lumene National Park',
#   'Kinshasa University',
#   'Ma Vallee',
#   'Cathedral of Lubumbashi',
#   'Lomako-Yokokala Faunal Reserve',
#   'Le Premier Shopping Mall',
#   'Academie des Beaux-Arts',
#   'Musee National de Kinshasa (National Museum)',
#   'Texaf Bilembo',
#   'Jardin Botanique de Kisantu',
#   'Zongo Falls',
#   'Serpents du Congo',
#   "Place De l'Echangeur",
#   'Lola ya Bonobo',
#   "Galerie d'Art Contemporain du Musee D'Art de Lubumbashi",
#   'Eglise CBFC-Gombe',
#   'Jardin Zoologique',
#   'Okapi Wildlife Reserve',
#   'Mount Nyiragongo',
#   'Lake Kivu',
#   'Kahuzi-Biega National Park',
#   'Symphonie des Arts',
#   'Lubumbashi Zoo',
#   'Mount Mangengenge',
#   'Marche Nouveau DAIPN',
#   'Virunga National Park',
#   'Paroisse Sainte Anne',
#   'Cathedrale Notre-Dame Du Congo',
#   'Congo River'],
#  'Congo': ['Parc de la Vallee de la Nsele',
#   'Bombo Lumene National Park',
#   'Kinshasa University',
#   'Ma Vallee',
#   'Cathedral of Lubumbashi',
#   'Lomako-Yokokala Faunal Reserve',
#   'Le Premier Shopping Mall',
#   'Academie des Beaux-Arts',
#   'Musee National de Kinshasa (National Museum)',
#   'Texaf Bilembo',
#   'Jardin Botanique de Kisantu',
#   'Zongo Falls',
#   'Serpents du Congo',
#   "Place De l'Echangeur",
#   'Lola ya Bonobo',
#   "Galerie d'Art Contemporain du Musee D'Art de Lubumbashi",
#   'Eglise CBFC-Gombe',
#   'Jardin Zoologique',
#   'Okapi Wildlife Reserve',
#   'Mount Nyiragongo',
#   'Lake Kivu',
#   'Kahuzi-Biega National Park',
#   'Symphonie des Arts',
#   'Lubumbashi Zoo',
#   'Mount Mangengenge',
#   'Marche Nouveau DAIPN',
#   'Virunga National Park',
#   'Paroisse Sainte Anne',
#   'Cathedrale Notre-Dame Du Congo',
#   'Congo River'],
#  'Cook Islands': ['Punanga Nui',
#   'Cook Island Christian Church (CICC)',
#   'Takitumu Conservation Area',
#   'Koteka Winery',
#   'Discover Marine and Wildlife Eco Centre',
#   'Ngatangiia Harbour',
#   "Papua ( Wigmore's) Waterfall",
#   'Aroa Marine Reserve',
#   'Tikioki Marine Reserve',
#   'Moturakau',
#   'Muri Night Market',
#   'One Foot Island',
#   'Matutu Brewery',
#   'Muri Lagoon',
#   'Te Ara- Cook Islands Museum of Cultural Enterprise',
#   'Maire Nui Botanical Gardens',
#   'Hospital Hill Lookout',
#   'Te Rua Manga (The Needle)',
#   'Aitutaki Lagoon',
#   'Aroa Beach',
#   'Arai-Te-Tonga',
#   "Tai's Weather Rock",
#   "Bonefish - E2's Way",
#   'Aitutaki Secret Garden',
#   'Black Rock Beach',
#   "O'otu Beach",
#   'LEK Rarotonga',
#   'Cook Islands Cultural Village',
#   'Titikaveka Beach',
#   'Mount Maungapu'],
#  'Colombia': ['Gold Museum (Museo del Oro)',
#   'Playa de Spratt Bight',
#   'Bioparque Los Ocarros',
#   'Combeima Canyon',
#   'Plaza Mayor',
#   'Piedra Del Penol',
#   'Walled City of Cartagena',
#   'Medellin Metrocable',
#   'Parque Nacional de Chicamocha',
#   'Ciudad Perdida',
#   'Mount Monserrate',
#   'La Casa del Libro Total',
#   'Bosques de Cocora',
#   'Casa Terracota',
#   'Parque Nacional Natural Tayrona',
#   'Museo del Caribe',
#   'La Piscinita',
#   'Laguna de Guatape',
#   'Carnaval de Barranquilla',
#   'Nevado Santa Isabel',
#   'Nevado del Ruiz',
#   'Museo Botero del Banco de la Republica',
#   'Centro Comercial Buenavista',
#   'Museo Aereo Fenix',
#   'Primavera Urbana',
#   'Gran Malecon Puerta de Oro',
#   'Cayo El Acuario',
#   'Aviario Nacional de Colombia',
#   'Zoologico de Cali',
#   'Johnny Cay'],
#  'Comoros': ['Mosquee du Vendredi',
#   'Mount Karthala',
#   'Kave Hoani',
#   'Chissioua Ouenefou',
#   'Grand Mosque du Vendredi',
#   'Bouni Beach',
#   'Chomoni Beach',
#   'Mitsoudje',
#   'Nioumachoua Beach',
#   'Mssihiri wa Cheik Ahmed Mosque',
#   'Plage Al Amal',
#   'National Museum of the Comoros',
#   'Domoni Beach',
#   'Chindini Beach',
#   'Ntingui Mountain Peak',
#   "Sultan's Palace",
#   'Miringoni Beach',
#   'Plage de Moya',
#   'Dziancoundre Waterfall'],
#  'Cabo Verde': ['Monte Curral',
#   'Deserto de Viana',
#   'Sal Paraiso Natural Pool',
#   'Santa Monica Beach',
#   'Praia de Chaves',
#   'Praia Santa Monica',
#   'Quebra Canela Beach',
#   'Praia de Santa Maria',
#   'Mercado de Sucupira',
#   'Serra de Malagueta',
#   'Monte Verde',
#   'Farol de D. Maria Pia',
#   'Fontona',
#   'Cabo Santa Maria',
#   'Buracona - Olho Azul',
#   'Paul Tal',
#   'Fontainhas',
#   'Praia da Laginha',
#   'Project Biodiversity Turtle Conservation Hatchery',
#   'Sabura Center',
#   'Paroquia de Nossa Senhora das Dores',
#   'Pedra Lume Salt Crater',
#   'Chapel of Our Lady of Fatima',
#   'Eliseu',
#   'Nazarene Church',
#   'Viveiro, Botanical Garden & Zoo di Terra',
#   'Casino Royal',
#   'Funana Casa da Cultura',
#   'Praca Alexandre Albuquerque',
#   'Spiaggia Di Curralinho'],
#  'Costa Rica': ['Curi Cancha Reserve',
#   'Coco Water Taxi',
#   'El Trapiche Tour',
#   'Arenal Volcano',
#   'Rincon de La Vieja National Park',
#   'Playa Biesanz',
#   'Puerto Viejo Beach',
#   'Pura Vida Gardens and Waterfalls',
#   'Teatro Nacional Costa Rica',
#   'Tortuga Island',
#   'Uvita Beach',
#   'Tio Leo Coffee Tour',
#   'Playa Santa Teresa',
#   'La Fortuna Waterfall',
#   'Hacienda Alsacia Starbucks Coffee Farm',
#   'Palo Verde National Park',
#   'Playa Manuel Antonio',
#   'Marina Pez Vela',
#   'Samara Beach',
#   'Ponderosa Adventure Park',
#   'Ecotermales Fortuna',
#   'Los Campesinos Reserve',
#   'Tamarindo Beach',
#   'Playa Espadilla Norte',
#   'Catarata Bijagual',
#   'Arenal Hanging Bridges',
#   'Pre-Columbian Gold Museum',
#   'Tico Pod Art House & Gifts',
#   'Neo Fauna CR',
#   'Mirador de Jaco'],
#  'Cuba': [],
#  'Curaçao': [],
#  'Christmas Island': [],
#  'Cayman Islands': [],
#  'Cyprus': ["Aphrodite's Rock Brewing Company",
#   'Pafos Zoo',
#   'Omodos Village',
#   'Cyprus Museum',
#   'Agios Neophytos Monastery',
#   'Buyuk Han',
#   'Avakas Gorge',
#   'Limassol Marina',
#   'Tombs of the Kings',
#   'Pivo microbrewery',
#   'Paphos Aphrodite Waterpark',
#   'Konnos Bay',
#   'Blue Lagoon',
#   'Saint Hilarion Castle',
#   'Salamis',
#   'Church of Profitis Elias',
#   'Ghost Town Famagusta',
#   'WaterWorld Themed Waterpark - Ayia Napa, Cyprus',
#   'The House of Dionysus',
#   'Agios Lazaros',
#   'Fig Tree Bay',
#   'Nissi Beach',
#   "George's Ranch",
#   'Kato Paphos Archaeological Park',
#   'Horse Riding Paphos - Eagle Mountain Ranch',
#   'Paphos Harbour and Port',
#   'Kourion',
#   'Makronissos Beach',
#   'Bellapais Monastery',
#   'Lara Bay Turtle Conservation Station'],
#  'Czechia': ['iQLANDIA',
#   'Prague Castle',
#   'Holy Trinity Column',
#   'Charles Bridge',
#   'Prague Zoo',
#   'Lesser Town',
#   'Villa Tugendhat',
#   'Lobkowicz Palace',
#   'Spilberk Castle',
#   'Konopiste Castle',
#   'Cathedral of St. Peter and St. Paul',
#   'Zoo Ostrava',
#   'Cesky Krumlov Castle',
#   'Katedrala sv. Vaclava',
#   'VIDA! Science Centre',
#   'Diana Lookout Tower',
#   'Pilsner Urquell Brewery',
#   'Mlynska kolonada',
#   "St Barbara's Cathedral",
#   'Obecni Dum',
#   'StaromEstske namEsti',
#   'Historic Center of Cesky Krumlov',
#   'Brno Technical Museum',
#   'Stara Louka',
#   'Pravoslavny Kostel Svateho Petra a Pavla',
#   'Black Tower (Cerna vez)',
#   'Ossuary / The Cemetery Church',
#   'Katedrala Svateho Vita',
#   'Dolni Vitkovice',
#   'Vysehrad National Cultural Monument'],
#  'Germany': ['Classic Remise Dusseldorf',
#   'English Garden',
#   'Miniatur Wunderland',
#   'Haus der Geschichte der Bundesrepublik Deutschland',
#   'Zwinger',
#   'Signal Iduna Park',
#   'The New Town Hall',
#   'Green Vault',
#   'Heidelberg Palace',
#   'Rhine Valley',
#   "Queen Mary's Bridge (Marienbrucke)",
#   "The Eagle's Nest",
#   'Altstadt',
#   'Zugspitze',
#   'Leipzig Zoo (Zoologischer Garten Leipzig)',
#   'Lake Constance (Bodensee)',
#   'Marienplatz',
#   'Herrenhaeuser Garten',
#   'Reichstag Building',
#   'Staedel Museum',
#   'Cablecar Koblenz',
#   'Isle of Mainau',
#   'Sanssouci Park',
#   'Freiburg Cathedral',
#   'Kolner Dom',
#   'Lichtentaler Allee',
#   'Rheinuferpromenade',
#   'Schnoor Viertel',
#   'Aachen Cathedral (Dom)',
#   'Mercedes-Benz Museum'],
#  'Djibouti': ['Sada Mosque',
#   'Rushing Waters Adventures',
#   'Al Molk Mosque',
#   'Arta Beach',
#   'Lake Assal',
#   'Lac Abbe',
#   'Grande Pecherie',
#   'Lake Assal',
#   'Dolphin Excursions Djibouti',
#   "L'ELIXIR parfumerie",
#   'Day Forest National Park',
#   'Hamoudi Mosque',
#   'Aden Fishing',
#   'Lake Abbe',
#   'Khor Ambado Beach',
#   'Djibouti Kitesurf',
#   'Place Menelik'],
#  'Dominica': [],
#  'Denmark': ['Aalborg Zoologiske Have',
#   'The Black Diamond - Royal Danish Library',
#   'Grenen',
#   'Moesgaard Museum',
#   'Trapholt',
#   'Roskilde Domkirke',
#   'Aros Aarhus Kunstmuseum',
#   'Rabjerg Mile',
#   'Christiansborg Slot',
#   'Romo Island',
#   'Universe',
#   'Torvehallerne',
#   'Rosenborg Castle',
#   'Nyhavn',
#   'Oekolariet',
#   'LEGO House',
#   'Kronborg Slot',
#   'Koldinghus',
#   'Frederiksberg Slot',
#   "Our Saviour's Church",
#   'Lindholm Hoeje Museum',
#   'Den Gamle By',
#   'Hammershus',
#   'Copenhagen ZOO',
#   'Tivoli Gardens',
#   'Tirpitz',
#   'Mandoe',
#   'Egeskov Castle',
#   'Fisheries- and Maritime Museum',
#   'LEGOLAND Billund'],
#  'Dominican Republic': [],
#  'Algeria': ['Emir Abdelkader Mosquee',
#   'Musee National du Bardo',
#   'Park Mall',
#   'Fort Santa Cruz',
#   'Pont Sidi M’Cid',
#   'Le Bastion 23 - Palais des Rais',
#   "Palais d'Ahmed Bey",
#   'La Playa',
#   'Memorial du Martyr',
#   'La Rue Didouche Mourad',
#   'Pic des Singes',
#   'Promenade des Sablettes',
#   'Timgad',
#   'Place du 1er Novembre 1954',
#   'Kasbah of Algiers',
#   'Citadelle et Palais El Mechouar',
#   'Chrea National Park',
#   'Caves of Jijel',
#   'Musee des Antiquites',
#   'Ketchaoua Mosque',
#   "Le Jardin d'Essai du Hamma",
#   'Hadjadj Plage',
#   "Basilique Notre Dame d'Afrique",
#   "Tassili n'Ajjer",
#   'Cap Carbon',
#   'Basilique Saint Augustin',
#   'Chapelle de Santa Cruz',
#   'Parc Animalier de Kissir - El Aouana',
#   'Le Port de Sidi Fredj',
#   "La Grande Poste d'Alger"],
#  'Ecuador': ["The Devil's Nose Train Ride",
#   'Reserva El Chato',
#   'Galapagos Beach at Tortuga Bay',
#   'South Plaza Island',
#   'El Cajas National Park',
#   'Malecon 2000',
#   'La Loberia',
#   "Pailon del Diablo (Devil's Cauldron)",
#   'Administracion Turistica del Parque Nacional Galapagos',
#   'Fundacion Iglesia de la Compania',
#   'Cerro Santa Ana',
#   'Pro Bici',
#   'Mariposas de Mindo - Butterfly Garden',
#   'Darwin Island',
#   'Nambilla Cascadas',
#   'Las Grietas',
#   'San Francisco Church (Iglesia de San Francisco)',
#   'Darwin & Wolf Islands',
#   'Quito Old Town',
#   'Las Penas',
#   'Basilica del Voto Nacional',
#   'El Panecillo',
#   'Charles Darwin Research Station',
#   'Hacienda La Danesa Lodge',
#   'Museo Templo del Sol Pintor Ortega Maila',
#   'Mindo Nambillo Cloud Forest Reserve',
#   'Parque Historico Guayaquil',
#   'Teleferico Quito',
#   'Guayasamin Museum',
#   'La Capilla Del Hombre'],
#  'Egypt': ['Saqqara (Sakkara) Pyramids',
#   'Jungle Aqua Park',
#   'SOHO Square',
#   'Ras Mohamed National Park',
#   'Hurghada Marina',
#   'Blue Hole',
#   'Memphis and Sakkara',
#   'Sharm El Luli',
#   'Mosque of Muhammad Ali',
#   'Nile River',
#   'Coptic Cairo',
#   'Abu Tig Marina',
#   'Bibliotheca Alexandrina',
#   'Mahmya Island',
#   'Senzo Mall',
#   'Egyptian Antiquities Museum',
#   'Montazah Gardens',
#   'Tiran Island',
#   'Gizeh Plateau',
#   'Temple of Karnak',
#   'Great Sphinx',
#   'Hurghada Grand Aquarium',
#   'Temple of Philae',
#   'Great Pyramid of Cheops (Khufu)',
#   'Luxor Temple',
#   'Makadi Water World',
#   'Mini Egypt Park',
#   'Pyramids of Giza',
#   'Giftun Islands',
#   'Valley of the Kings'],
#  'Eritrea': ['Memorial Plaza for Victims of Massawa Battle',
#   'Cattedrale di Asmara',
#   'Asmara Central Market',
#   'Denkalya Desert',
#   'Fiat Tagliero',
#   'Massawa Mosque',
#   "Former Banco d'Italia",
#   'Al Khulafa Al Rashiudin Mosque',
#   'Cinema Roma',
#   'Covered Bazaar',
#   'Keren War Cemetery',
#   'Enda Marian- Cattedrale Copta Di Asmara',
#   "Mariam Da'arit",
#   'Dahlak Archipelago National Park',
#   'St. Mariam Cathedral',
#   'National Museum Asmara',
#   'Synagogue of Asmara',
#   'Tank Graveyard',
#   'Adulis',
#   'Nda Mariam Othodox Church',
#   'Liberation Avenue',
#   'Debre Bizen',
#   'Ministry of Tourism - Tourism Information Office',
#   'Medebar Market',
#   'Shaafi Mosque',
#   'Cimitero Italiano Di Asmara',
#   'Former Imperial Palace',
#   'Metera',
#   'Asmara Theater and Opera House',
#   'Qohaito'],
#  'Western Sahara': ['Assona Mosque',
#   'St. Francis of Assisi Cathedral',
#   'Our Lady of Mount Carmel Church',
#   "L'ile Herne",
#   'Parque Jardin Laayoune',
#   'Centre Artisanal',
#   'Laayoune Grand mosque'],
#  'Spain': ['Piramide de Arona',
#   'Prado National Museum',
#   'Picos de Europa',
#   'Feria del Caballo',
#   'Museo Automovilistico y de la Moda',
#   'Plaza Mayor',
#   'Es Vedra',
#   'Volcan El Teide',
#   'Parque De La Paloma',
#   'Basilica of the Sagrada Familia',
#   'Parque Natural de Cabo de Gata',
#   'Loro Parque',
#   'Guggenheim Museum Bilbao',
#   'La Concha Beach',
#   'Real Alcazar',
#   'Catedral Primada',
#   'Islas Cies',
#   'Catedral de Mallorca',
#   'Basilica de Nuestra Senora del Pilar',
#   'Playa de Ses Illetes',
#   'Siam Park',
#   'Corralejo Dunes',
#   'PortAventura',
#   'Puente Nuevo Bridge',
#   'The Alhambra',
#   'Montgo Natural Park',
#   'El Casco Antiguo de Benidorm',
#   'Central Market of Valencia',
#   'Serra de Tramuntana',
#   'Mezquita Cathedral de Cordoba'],
#  'Estonia': ['Kadriorg Park',
#   'Prison Escape',
#   'Narva Joesuu',
#   'AHHAA Science Centre',
#   'Ruins of the Viljandi Order Castle',
#   'Estonian National Museum',
#   'Toompea Hill',
#   'Kuressaare Castle',
#   'Haapsalu Castle',
#   'Printing and Paper Museum',
#   'St. Olaf’s Church',
#   'Tallinna Teletorn',
#   'Alpakafarm',
#   'Rakvere Castle',
#   'Tallinn Old Town',
#   'Tallinna Raekoja Plats',
#   'Aleksander Nevski Katedraali',
#   'Haapsalu Old Town',
#   'Eesti Vabaohumuuseum',
#   'Narva Castle',
#   'Africa Beach and Promenade',
#   'Lennusadam Seaplane Harbour',
#   'Parnu Beach Promenade',
#   'Tartu University Botanical Garden',
#   'Tartu Toy Museum',
#   'Saaremaa Museum',
#   'Lahemaa National Park',
#   'Tartu Old City',
#   'Lottemaa',
#   'Tervise Paradiis Water Park'],
#  'Ethiopia': [],
#  'Finland': ['Pilke Science Centre',
#   'Finnish Air Force Museum',
#   'Seurasaari Island and Open-Air Museum',
#   'Nuuksio National Park',
#   'SantaPark - the Home Cavern of Santa Claus',
#   'Arktikum',
#   'Sea Fortress Suomenlinna',
#   'Vapriikin Museokeskus',
#   'Ruka',
#   'Ruka',
#   'Tampereen Tuomiokirkko',
#   'Saimaa Canal',
#   'Rovaniemi Church',
#   'Santa Claus Office',
#   'Heureka',
#   'Temppeliaukion Church',
#   'Ice Karting Levi',
#   'Santa Claus Village',
#   'Turku Castle',
#   'Santa Claus Secret Forest - Joulukka',
#   'Yllas Ski Resort',
#   'Ounasvaaran Hiihtokeskus Oy',
#   'Nallikari Beach',
#   'Urho Kekkonen National Park',
#   'Angry Birds Park',
#   "Lumberjack's Candle Bridge",
#   'Pyynikki Park and Observation Tower',
#   'Old Market Hall',
#   'Porvoo Old Town',
#   'Ainolan Puisto'],
#  'Fiji': ['Garden of the Sleeping Giant',
#   'Sigatoka Sand Dunes National Park',
#   'Sabeto Hot Springs and Mud Pool',
#   'Dravuni Island',
#   'Naihehe Caves',
#   'Navala Village',
#   'Big Bula Water Park',
#   'Prestige Laundry',
#   'Colo-I-Suva Forest Park',
#   'Tavoro Waterfalls',
#   'Tivua Island Fiji',
#   'Natadola Beach',
#   'Fiji Culture Village',
#   'Lau Group',
#   'Walu Water Sports Ltd.',
#   'Momi Bay Battery Historic Park',
#   'Robinson Crusoe Island',
#   'Biausevu Waterfall',
#   'Nadi Produce Markets',
#   'Nausori Highlands',
#   'Suva Municipal Market',
#   'Koroyanitu National Heritage Park',
#   'Sri Siva Subramaniya Temple',
#   'Kula Wild Adventure Park',
#   'Fiji Museum',
#   'Albert Park',
#   'Fiji Airways Premier Lounge',
#   'Paradise Beach',
#   'Port Denarau Marina',
#   'Pacific Harbour Information & Booking Centre'],
#  'Falkland Islands (Malvinas)': ['Volunteer Point',
#   'Mount Usborne',
#   'Falkland Islands Museum',
#   'Christ Church Cathedral',
#   'Mount Maria',
#   'Kelp Point',
#   'Cape Bougainville',
#   'Battle Memorial',
#   'Surf Bay',
#   'Bluff Cove Lagoon',
#   'New Island Conservation Trust',
#   '1982 Liberation Memorial',
#   'Museum Britannia House',
#   'Cape Pembroke Lighthouse',
#   'Argentine Military Cemetery',
#   'Sea Lion Island',
#   "Devil's Nose",
#   'St. Mary s Catholic Church',
#   'Weddell Island',
#   'Bleaker Island',
#   'Saunders Island',
#   'Blue Beach Military Cemetery',
#   'Mount Longdon',
#   'Elephant Beach Farm',
#   'Pebble Island',
#   'Lady Elizabeth Shipwreck',
#   'Gypsy Cove',
#   'Carcass Island',
#   "Bertha's Beach",
#   'Whalebone Arch'],
#  'France': ['Cathedrale Notre Dame de Strasbourg',
#   'Parc du Thabor',
#   'Castle Hill of Nice',
#   'Aiguille du Midi',
#   'Musee Departemental Arles Antique',
#   'Walt Disney Studios Park',
#   'Cathedrale Notre-Dame de Reims',
#   "Musee de l'Hotel-Dieu",
#   'Disneyland Paris',
#   'Nature Reserve of Scandola',
#   "Saint Catherine's Church",
#   'Jardin des Plantes',
#   'La Petite France',
#   "Musee d'Orsay",
#   'Metz Cathedral',
#   'Abbaye du Mont-Saint-Michel',
#   'Sentier Blanc-Martel',
#   'Basilique Notre Dame de la Garde',
#   'Hotel Pams',
#   'Vieux Lyon',
#   "Lac d'Annecy",
#   "Le Sentier du Littoral, Cap d'Antibes",
#   'Cathedrale Notre-Dame de Rouen',
#   'Musee du Cinema et de la Miniature',
#   'Calanques',
#   'Montagne Sainte Victoire',
#   'Parc national des Calanques',
#   'Cathedrale Notre-Dame de Paris',
#   'Old Town',
#   "Falaises d'Etretat"],
#  'Faroe Islands': ['Risin and Kellingin',
#   'Listasavn Foroya',
#   'Christianskirkjan',
#   'Torshavn Cathedral',
#   'Eggjarnar',
#   'Nolsoy',
#   'Fugloy',
#   'The Faroe Islands Aquarium',
#   'Vioarlundin Park',
#   'Akraberg Lighthouse',
#   'Kalsoy',
#   'Kopakonan',
#   'Hvannhagi',
#   'Trollkonufingur',
#   'Foroya Bjor',
#   'Mulafossur Waterfall',
#   'Tourist Information Centre',
#   'Skansin Fortress',
#   'Kaldbak Kirkja',
#   'Asmundarstakkur',
#   'Vestmanna Bird Cliffs',
#   'The Nordic House',
#   'Lake Leitisvatn',
#   'Cleft Of Gjogv',
#   'Mykines Holmur Lighthouse',
#   'Kirkjubour Cathedral',
#   'Saksun Church',
#   'National Museum of the Faroe Islands',
#   'Tinganes',
#   'Gasadalur Tunnel'],
#  'Micronesia, Federated States of': ['The Ethnic Art Institute of Micronesia',
#   'Ant Atoll',
#   'Kepirohi Waterfall',
#   'Protestant Church',
#   'Stone Money',
#   'Pohnpaid Petroglyphs',
#   'Bechyal Cultural Center',
#   'Japanese Zeros',
#   'Truk Lagoon',
#   'Tamilyog Trail',
#   'Nan Madol',
#   'Utwe-Walung Marine Park',
#   'The Blue Hole',
#   'Colonia Bridge',
#   'Lelu Island',
#   'Yap Art Studio Gallery',
#   'Yela Valley Ka Forest',
#   'Pilen Seleur Eel Pools',
#   'Kolonia',
#   'Mt. Pwusehn Malek',
#   'Kuop Atoll',
#   'Liduduhniap Falls',
#   'Qaldung',
#   "Hiroshi's Point",
#   'Immaculate Heart of Mary Cathedral',
#   'Gacham (Grand Canyon)',
#   'Pohnpei State Botanical Garden',
#   'Lelu Harbor',
#   'Sunset Park',
#   'Sokehs Rock'],
#  'Gabon': ['Sainte-Anne du Fernand Vaz',
#   "Stade d'Angondje",
#   "L'Eglise St-Michel Libreville",
#   'Musee des Arts et Traditions du Gabon (Museum of Art and Culture)',
#   'Ivindo National Park',
#   'Pointe-Denis Beach',
#   'Cecado Glass',
#   'Reserve de la Lope',
#   'Notre-dame de Lourdes',
#   'Cathedrale Saint Pierre',
#   'Palais Presidentiel',
#   'Cour Constitutionnelle de la Republique Gabonaise',
#   'Casino Croisette',
#   'St Marie Cathedral',
#   'Institut francais',
#   'Cathedrale Saint Louis',
#   'Memorial Leon Mba',
#   'Gabon Wildlife Camps',
#   'Museum Albert Schweitzer',
#   'Hassane II Mosque',
#   'Pongara National Park',
#   "Diocese d'Oyem",
#   'Akanda National Park'],
#  'United Kingdom': ['Alton Towers',
#   'York Minster',
#   'The Roman Baths',
#   'Windsor Castle',
#   'Helvellyn',
#   'National Museum of Scotland',
#   'Chester Zoo',
#   'The Mary Rose Museum',
#   'Tower of London',
#   'Camera Obscura and World of Illusions',
#   'Royal Yacht Britannia',
#   'Churchill War Rooms',
#   'Tower Bridge',
#   'Edinburgh Old Town',
#   'Victoria Tunnel',
#   'Blackpool Pleasure Beach',
#   "Arthur's Seat",
#   "St. George's Chapel",
#   'Derwentwater',
#   'Catbells Lakeland Walk',
#   'Turbary Woods Owl and Bird of Prey Sanctuary',
#   'Stonehenge',
#   "Brunel's SS Great Britain",
#   'Shambles',
#   'Gower Peninsula',
#   'Birmingham Back to Backs',
#   'National Railway Museum',
#   'The British Museum',
#   'Eden Mill',
#   'Kelvingrove Art Gallery and Museum'],
#  'Georgia': [],
#  'Guernsey': [],
#  'Ghana': [],
#  'Gibraltar': [],
#  'Guinea': ['Les Cascades De La Soumba',
#   'Sante Marie Cathedral',
#   'Le Voile de la Mariee',
#   'Conakry Grand Mosque',
#   'National Museum (Musee National)',
#   'Fouta Trekking Adventure',
#   'Skylight',
#   'Rachette Metamorphose',
#   'Iles de Los',
#   'CanalOlympia Kaloum',
#   "L'After - Billard",
#   'Mount Nimba Strict Nature Reserve',
#   'Crisber Night Club International',
#   'Skylight',
#   'Baie bayoum',
#   'Mls',
#   'Shine Spa for Sheraton Conakry'],
#  'Guadeloupe': [],
#  'Gambia': ['Bijilo Forest Park',
#   'Tanje Village Museum',
#   'Bakau Fish Market',
#   'Kunta Kinteh Island',
#   'Brikama Craft Market',
#   'Stone Circles of Senegambia',
#   'River Gambia National Park',
#   'Gunjur Village Museum',
#   'King Fahad Mosque',
#   'Arch 22',
#   'Jufureh',
#   'Banjul - Barra Ferry Service',
#   'The Reptile Farm',
#   'Fort James Island',
#   'Stone Circles of Senegambia',
#   'Lemonfish Art Gallery',
#   'Youth Monument',
#   'Katchikally Crocodile Pool',
#   'Fort Bullen',
#   'Kololi',
#   'Makasutu Culture Forest',
#   'Albert Market',
#   'Abuko Nature Reserve',
#   'National Museum',
#   'Kiang West National Park',
#   "Bakau's Botanical Gardens",
#   'Kotu Beach',
#   'Pipeline Mosque',
#   'Tanji / Karinti Bird Reserve',
#   'Roman Catholic Cathedral'],
#  'Guinea-Bissau': ['Bissau Main Market',
#   'Centro Artistico Juvenil',
#   'Balafon Pub Bar',
#   'Fortaleza de Sao Jose da Amura',
#   'Mesquita Bissau',
#   'Mercado Central',
#   'Presidential Palace',
#   'Igreja Catolica da Bissau',
#   'Museu Nacional'],
#  'Equatorial Guinea': ['Elobey Grande',
#   'Centro Cultural de Espana en Malabo',
#   'Catedral de Ebebiyin',
#   'Islas Elobey',
#   'The Malabo National Park',
#   'Iglesia de San Fernando',
#   'Bata Cathedral',
#   'Catedral Basilica de La Inmaculada Concepcion',
#   'Pico Basile',
#   'Catedral de Santa Isabel',
#   'Arena Blanca',
#   'Elobey Chico',
#   'Equatorial Guinea Bodypainting Festival',
#   'La Casa Verde',
#   'Nuevo Estadio de Malabo'],
#  'Greece': ['Old Venetian Harbor',
#   'Egremni Beach',
#   'Archaeological Museum of Piraeus',
#   'Cretan Olive Oil Farm',
#   'Elafonissi Beach',
#   'Corfu Old Town',
#   'Monolithos Castle',
#   'Balos Lagoon',
#   'Church of Agios Dimitrios',
#   'Marathonisi (Turtle Island)',
#   'Ladadika District',
#   'Paleokastritsa Monastery',
#   'Archaeological Museum of Thessaloniki',
#   'Plaka Forest',
#   'Giorgos Karaiskakis Stadium',
#   'Village of Lindos',
#   'Water Park',
#   'Angelokastro',
#   'Hiking Trail Fira - Oia',
#   'Rethymnon Old Town',
#   'Little Venice',
#   'Palace of the Grand Master of the Knights of Rhodes',
#   'Heraklion Archaeological Museum',
#   'Aquaworld Aquarium & Reptile Rescue Centre',
#   'Acropolis',
#   'Medieval City',
#   'Porto Limnionas Beach',
#   'Imbros Gorge',
#   'Amoudi Bay',
#   'Sarakiniko Beach'],
#  'Grenada': [],
#  'Greenland': ['Nuuk Art Museum',
#   'Kangerlussuaq Museum',
#   'Greenland National Museum and Archives',
#   'Church of Kap Dan',
#   'Disko Island',
#   'Qaanaaq Museum',
#   'Tasersuaq',
#   'Ilulissat Icefjord',
#   'Ilulissat Art Museum',
#   'Saviors Church',
#   'Kap Hope',
#   'Eqip Sermia Glacier',
#   'Hvalsey Church Ruins',
#   'Sisimiut Museum',
#   'Katuaq Cultural Centre',
#   'Kulusuk Museum',
#   'Nuuk Cathedral',
#   'Sondre Stromfjord',
#   'Ammassalik Museum',
#   'World of Greenland',
#   'Qaqortoq Museum',
#   'The Fjord of Eternity',
#   'Fredens Kirke',
#   'Ilulissat Museum',
#   'Northeast Greenland National Park',
#   'Qornok',
#   'Narsarsuaq Museum',
#   'Nanortalik Open Air Museum',
#   'Thule Air Base',
#   'Sermermiut'],
#  'Guatemala': ['Playa Blanca',
#   'Caoba Farms',
#   'La Aurora Zoo',
#   'Paseo Cayala',
#   'Santa Maria Volcano',
#   'Mundo Petapa Irtra',
#   'Iglesia de San Francisco El Grande',
#   'Xetulul',
#   'Semuc Champey',
#   'Tikal National Park',
#   'Museo Popol Vuh',
#   'Lake Atitlan',
#   'Volcan San Pedro',
#   'Laguna Chicabal',
#   'The Plaza Central Park',
#   'Orquigonia',
#   'Plaza Fontabella',
#   'Rio Dulce',
#   'Museo Ixchel del Traje Indigena',
#   'Oakland Mall',
#   'Arco de Santa Catalina',
#   'Hotel Atitlan Gardens',
#   'Iximche',
#   'Pacaya Volcano',
#   'Indian Nose',
#   'Cerro de la Cruz',
#   "Jorge's Rope Swing",
#   'Casa Santo Domingo Museums',
#   'ChocoMuseo',
#   'Acatenango Volcano'],
#  'French Guiana': ['Place des Palmistes',
#   'Office du tourisme de Saint-Laurent du Maroni',
#   'Domaine Pascaud',
# ...
#   'Arbob Cultural Palace',
#   'Nurek Dam',
#   'National Museum of Tajikistan',
#   'Green Bazaar',
#   'Fann Mountains',
#   'Hisor Fortress',
#   'Historical Local Lore Museum of Archeology and Fortification',
#   'Victory Park',
#   'Delfin Aquapark',
#   'Ayni Opera & Ballet Theatre',
#   'Gurminj Museum of Music Instruments',
#   'Seven Lakes',
#   'NOOR ART GALLERY',
#   'Park Kamal Khudzhandi',
#   'Mevlana Yakub Charki Mosque',
#   'Pamir Highway',
#   'Yagnob Valley',
#   'House Museum Kamal Khuzhandi',
#   'Kayrakkum Reservoir',
#   'Ismaili Centre',
#   'Sacred Spring Chiluchor Chashma',
#   'Rudaki Park',
#   'Iskanderkul Lake',
#   'Boghi Poytakht Park',
#   'Lake Karakul',
#   'National Library of Tajikistan',
#   'National Museum of Antiquities',
#   'Statue of Ismoil Somoni'],
#  'Tokelau': [],
#  'Turkmenistan': ['Parthian Settlement of Nisa',
#   'Ashgabat Cable Car',
#   'Geokdepe',
#   'Gypjak Mosque',
#   'Dvor',
#   'Monument Arch of Neutrality',
#   'Kow Ata Underground Lake',
#   'Ashgabat National Museum of History',
#   'Palace Complex Oguzkhan',
#   'Wedding Palace',
#   'Berkarar',
#   'Turkmenistan Independence Monument',
#   'Turkmen Museum of Fine Arts',
#   'Halk Hakydasy Memorial Complex',
#   'Ashgabat Train Station',
#   'Kunya-Urgench',
#   'Ancient Merv',
#   'Russian Bazaar',
#   'Yangykala Canyon',
#   'Ashgabat hippodrome',
#   'Ertugrul Gazi Mosque',
#   'Turkmen Carpet Museum',
#   'Seyit Jemaletdin Mosque',
#   'Aerial Tramway',
#   'Abiverd Ruins',
#   'Tolkuchka-Basar',
#   '"Door to Hell" Gas Deposit',
#   'Druzhba Park',
#   'Russian Orthodox Church',
#   'World of Turkmenbashi Tales'],
#  'Timor-Leste': ['Immaculate Conception Cathedral',
#   'Marobo Hot Springs',
#   'Xanana Gusmao Reading Room',
#   'The Archives & Museum of East Timorese Resistance',
#   'Old Ai Pelo Prison',
#   'Tasitolu',
#   'Cristo Rei',
#   'Largo de Lecidere',
#   'Jaco Island',
#   'St. Anthony’s Cathedral',
#   'Piscina de Baucau',
#   'Tais Market',
#   'Mount Ramelau',
#   'Dare War Memorial Museum',
#   'Tiris Manumera',
#   'Nino Konis Santana National Park',
#   'One Dollar Beach',
#   'Arte Moris',
#   'Comarca Balide Prison',
#   'Chega! Exhibition',
#   'Akrema Beach',
#   'Lotus Warrior Tomb',
#   'Cemetery of Santa Cruz'],
#  'Tonga': ["St Joseph's Cathedral",
#   "Ha'amonga'a Maui Trilithon",
#   "Captain Cook's Landing Place",
#   'Mt Talau',
#   "Mapu'a 'a Vaea Blowholes",
#   'Anahulu Cave - The Underground Swimming Pool',
#   'Luahoko Robinson Island',
#   'Friends Tourist Center',
#   "Ene'io Botanical Garden",
#   'Talamahu Markets',
#   'Utakalongalu Market',
#   'Free Church of Tonga',
#   '3 Headed Coconut',
#   'Basilica of St Anthony of Padua',
#   'Royal Palace',
#   'Hufangalupe Natural Land Bridge',
#   'Royal Tombs',
#   'Centenary Church',
#   'Kingdomkoffie',
#   "Ha'atafu Beach",
#   'Abel Tasman Landing Site',
#   'Ancient Royal Tombs of Lapaha',
#   "St. Mary's Cathedral",
#   'Tonga Tourism Authority'],
#  'Trinidad and Tobago': [],
#  'Tunisia': ['Bourghiba Mausoleum',
#   'Noddy Train',
#   'Medina of Tunis',
#   'Djerbahood',
#   'Medina of Hammamet',
#   'Sentido Djerba Beach',
#   'Costa Mall',
#   'Museum Dar Essid',
#   'Yasmin Hammamet',
#   'George Sebastian Villa',
#   'Chott El Jerid',
#   'Musee des Religions',
#   'Hammamet Beach',
#   'Dar Am Taieb',
#   'Ribat of Monastir',
#   'El Ghriba Synagogue',
#   'Ribat',
#   'Medina of Sousse',
#   'Aqua Palace',
#   'Dar Jilani La maison des Arts & Metiers',
#   'Grosse Moschee von Sousse',
#   'Kasbah of Hammamet',
#   'The National Bardo Museum',
#   'Sousse Archaeological Museum',
#   'Krokodilfarm Animalia',
#   'Musee de Guellala',
#   'Sahara Desert',
#   'Magiceye Sousse',
#   'Carthage Land Hammamet',
#   'Djerba Explore'],
#  'Turkey': ['Kordonboyu',
#   'Saklikent Milli Parki',
#   'Kapikaya Canyon',
#   'Koprulu Kanyon Milli Parki',
#   'Lake Golcuk',
#   'Kaleici',
#   'Varda(Alman) Koprusu',
#   'AnItkabir',
#   'Kleopatra Beach',
#   'Sumela Monastery',
#   'Goreme National Park',
#   'Adaland',
#   'Canakkale Truva Heykeli',
#   'Ilica Plaji',
#   'Temple of Apollo',
#   'Castle of St. Peter',
#   'Museu a Ceu Aberto de Goreme',
#   'Alsancak',
#   'Oludeniz PlajI',
#   'TahtalI Dagi',
#   'Mevlana Muzesi',
#   'Bursa Teleferik',
#   'Hagia Sophia Museum / Church (Ayasofya)',
#   'Marmaris Marina',
#   'Izmir Wild Life Park',
#   'Devrent Valley',
#   'Kaputas Beach',
#   'Alanya Kalesi',
#   'Kemeralti Market',
#   'Dolmabahce Palace'],
#  'Tuvalu': ['Tuvalu National Library',
#   "Tuvalu Women's Handicraft Centre",
#   'Funafuti Marine Conservation Area',
#   'Tuvalu Philatelic Bureau'],
#  'Taiwan, Province of China': ["National Revolutionary Martyrs' Shrine",
#   'Taipei Confucius Temple',
#   'Elephant Mountain (aka Nangang District Hiking Trail)',
#   'Dalongdong Bao An Temple',
#   'Songshan Ciyou Temple',
#   'Fulong International Sand Sculpture Festival',
#   'Chishang Huanzhen Bicycle Path',
#   'Dashan Beiyue',
#   'Touliu',
#   'Yangmingshan National Park',
#   'Danshuei',
#   'Cingtian Ciliou',
#   'Taipei City Mall',
#   'Bitoujiao Trail',
#   'Miniatures Museum of Taipei',
#   'Nanyuan Garden Resort Farm',
#   'Longtan Tourist Pond',
#   'Chiang Kai-Shek Memorial Hall',
#   'Daan Forest Park',
#   'Dapo Pond',
#   'Sunglungyen Waterfall',
#   'Fulong Old Caoling Tunnel',
#   'National Palace Museum',
#   'Metro Walk Shopping Center - Taoyuan',
#   'Maokong Gondola',
#   'National Taichung Theater',
#   'Longshan Temple',
#   'Hsing Tian Kong',
#   'Christmasland in New Taipei City',
#   'Alang Yi Trail'],
#  'Tanzania, United Republic of': ['Bongoyo Island',
#   'Slipway Shopping Center',
#   'Jozani Chwaka Bay National Park',
#   'Ngorongoro Crater Conservation Area',
#   'Meserani Snake Park',
#   'Old Slave Market/Anglican Cathedral',
#   'AIM Mall',
#   'Tanzanite Experience',
#   'The School of St Jude',
#   'Mbudya island',
#   'Prison Island - Changuu Private Island',
#   'Engare sero waterfall',
#   'Materuni Waterfalls',
#   'Paje Beach',
#   'Seronera',
#   'Big Body With Tatata Spice Farm',
#   'Jambo Spice Farm',
#   'Ascend Tanzania',
#   'Nakupenda Beach',
#   'Lake Duluti',
#   'Stone Town',
#   'Ol Doinyo Lengai',
#   'Nungwi Beach',
#   'Kikuletwa Hotsprings',
#   'Cultural Heritage Centre',
#   'Serengeti National Park',
#   'Ngurdoto Crater',
#   "Cheetah's Rock",
#   'Mount Kilimanjaro',
#   'Joining Safaris'],
#  'Uganda': ['Lake Victoria',
#   'Uganda Reptile Village',
#   'Namirembe Kathedrale',
#   'Kasubi Tombs',
#   'Victoria Nile',
#   "Baha'i Temple",
#   'Uganda Martyrs Shrine',
#   'Source of the Nile - Speke Monument',
#   'Forest Park Resort',
#   'Uganda Wildlife Conservation Education Centre',
#   'Budongo Forest',
#   'Rubaga-Kathedrale',
#   'Nile Reptile Park',
#   'Bigodi Wetlands Sanctuary',
#   'Social Innovation Museum',
#   'Bwindi Impenetrable National Park',
#   'Ngamba Island Chimpanzee Sanctuary',
#   'The Acacia Mall',
#   'Great Adventures Uganda',
#   'Batwa Cultural Heritage',
#   'Gorilla Bookings',
#   'Entebbe Botanic Gardens',
#   'Bwindi Inpenetrable Forest',
#   'Itanda Falls',
#   'Mpanga Central Forest Reserve',
#   'Independence Monument',
#   'Uganda Museum',
#   'Sesse Islands',
#   'Lubiri Palace',
#   'Gaddafi National Mosque'],
#  'Ukraine': ['Menorah Centre',
#   'Museum of Folk Architecture and Life',
#   'Khortitsa National Nature Reserve',
#   'Rynok Square',
#   'Pirogovo Open-Air Museum',
#   'Great Patriotic War Museum',
#   'Sofiyivka Park',
#   'Rodina Mat (Motherland)',
#   'Lychakiv Cemetery',
#   'Old Town',
#   'Beer Cultural Experience Center “Lvivarnya”',
#   'Secrets of Underground Odessa Museum',
#   'Odessa Delphinarium Nemo',
#   'Gorky Central Park of Culture and Leisure',
#   'Dolphinarium Oskar',
#   'Lviv City Hall',
#   "Subcarpathian Rus' Museum of Folk Architecture and Customs",
#   'Saint Sophia Cathedral',
#   'Insomnia - The Haunted House',
#   'Kharkov Dolphinarium',
#   'Multimedia Fountain Roshen',
#   'Andriyivski Uzviz',
#   'Lviv National Opera',
#   'Odessa National Academic Opera and Ballet Theater',
#   'Olgi Kobylyanskoi Street',
#   'Probiy Waterfall',
#   'Nikolaev Zoo',
#   'Mykola Syadristy Microminiatures Museum',
#   'Deribasovskaya Street',
#   "Kyivo-Pechers'ka Lavra"],
#  'United States Minor Outlying Islands': [],
#  'Uruguay': ['Playa Mansa',
#   'Cerro Arequita',
#   'Gruta del Padre Pio',
#   'Mercado Agricola Montevideo - MAM',
#   'Rivera Casino & Resort',
#   'Bodega Boutique El Legado',
#   'Andes Museum',
#   'Palacio Legislativo',
#   'Palacio Salvo',
#   'Rambla de Montevideo',
#   'Ciudad Vieja',
#   'Montevideo Sign',
#   'Fortaleza de Santa Teresa',
#   'Minas de Corrales, Capital del Oro',
#   'Aquatic Park Termas de Salto Grande',
#   'Bouza Bodega Boutique',
#   'Cerro San Antonio',
#   'Pocitos',
#   'Plaza Independencia',
#   'Parque Rodo',
#   'Melancia Mall',
#   'Theatre Solis',
#   'Museo – Taller de Casapueblo',
#   'Acuamania',
#   'Valle del Lunarejo',
#   'Parque Salto del Penitente',
#   'Mercado del Puerto',
#   'Barrio Historico',
#   'Isla Gorriti',
#   'Bodega Cerro Chapeu'],
#  'United States': ['Chihuly Garden and Glass',
#   'USS Midway Museum',
#   'The National 9/11 Memorial & Museum',
#   'The Getty Center',
#   'Musical Instrument Museum',
#   'National Air and Space Museum',
#   'River Walk',
#   'Garden of the Gods',
#   'High Roller',
#   'Grand Canyon South Rim',
#   'Cleveland Museum of Art',
#   '17-Mile Drive',
#   'Grand Ole Opry',
#   'Alcatraz Island',
#   'Sight & Sound Theatres',
#   'The Ernest Hemingway Home and Museum',
#   'Freedom Trail',
#   'United States Holocaust Memorial Museum',
#   'Sugarlands Distilling Company',
#   'Central Park',
#   'Diamond Head State Monument',
#   'The National WWII Museum',
#   'Red Rock Canyon National Conservation Area',
#   'Clearwater Beach',
#   'Disney California Adventure Park',
#   'The Art Institute of Chicago',
#   'South Beach',
#   'The Wizarding World of Harry Potter',
#   'Savannah Historic District',
#   'Louisville Mega Cavern'],
#  'Uzbekistan': ['Shah-i-Zinda',
#   'State Museum "In Memory of the Victims of Repression"',
#   'Fine Arts Museum of Uzbekistan',
#   'Uzbekistan State Museum of Applied Art',
#   'Tashkent TV tower',
#   'Chimgon',
#   'Amir Timur Museum',
#   'Independence Square (Mustakillik Square)',
#   'Japanese Garden',
#   'Alisher Navoi National Park',
#   'Metro Taschkent',
#   'Sacred Heart of Jesus Cathedral',
#   'Minor Mosque',
#   'Gur Emir Mausoleum',
#   'Tashkent Zoo',
#   'Navoi Opera Theater',
#   'Registan',
#   'Ilkhom Theater',
#   'Chorsu Bazaar',
#   'Railway Museum',
#   'Monument of Courage Earthquake Memorial',
#   'Barak-Khan Madrassah',
#   'Mall Samarkand Darvoza',
#   'State Museum of History of Uzbekistan',
#   'Kukeldash Madrasah',
#   'Old Tashkent',
#   'Shopping Mall Next',
#   'Teleshayakh Mosque',
#   'Great Minaret of the Kalon',
#   'Amir Temur Square'],
#  'Holy See (Vatican City State)': [],
#  'Saint Vincent and the Grenadines': [],
#  'Venezuela, Bolivarian Republic of': ['Monumento Manto de Maria Divina Pastora',
#   'Cayo De Agua',
#   'Parque Fernando Penalver',
#   'Ciudad Universitaria de Caracas',
#   'Mercado Municipal de Chacao',
#   'Playa el Yaque',
#   'Centro de Arte Los Galpones',
#   'Casa Natal & Museo Bolivar',
#   'Laguna de Mucubaji',
#   'Paseo de Los Proceres',
#   'Museo de Bellas Artes',
#   'Plaza de Altamira',
#   'La Playa El Agua',
#   'Basilica Nuestra Senora de Chiquinquira',
#   'Isla Larga',
#   'Mercado Principal',
#   'Angel Falls',
#   'Laguna de la Restinga',
#   'El Laguito',
#   'Pico el Aguila Venezuela',
#   'Parque Nacional Sierra Nevada',
#   'Panteon Nacional',
#   'Iglesia Nuestra Senora de La Chiquinquira',
#   'Expanzoo Expansion Centro Educativo Recreacional',
#   'Paramo la Culata',
#   'Playa Parguito',
#   'Teleferico',
#   'Basilica Nuestra Senora Del Valle',
#   'Museo de Ciencias Naturales',
#   'Waterland'],
#  'Virgin Islands, British': [],
#  'Virgin Islands, U.S.': [],
#  'Viet Nam': ['Phong Nha Caves',
#   'Cai Rang Floating Market',
#   'Vietnam Museum of Ethnology',
#   'Lady Buddha',
#   'Halong Bay',
#   'Hue Imperial City (The Citadel)',
#   'Vinpearl Land Nha Trang',
#   'Hoi An Ancient Town',
#   'Cat Ba Island',
#   'Dragon Bridge',
#   'Paradise Cave',
#   'My Khe Beach',
#   'Phu Quoc Countryside',
#   'Tomb of Minh Mang',
#   'Vinpearl Safari',
#   'The Marble Mountains',
#   'Old Quarter',
#   'Christ the King',
#   'Cu Chi Tunnels',
#   'Ta Cu Mountain',
#   'War Remnants Museum',
#   'Trang An Grottoes',
#   'Elephant Falls',
#   'Muong Hoa Valley',
#   'Linh Phuoc Pagoda',
#   'Datanla Falls',
#   'Fansipan Mountain',
#   'Son Tra Mountain (Monkey Mountain)',
#   'Thien Vien Truc Lam',
#   'Ba Na Hills'],
#  'Vanuatu': [],
#  'Wallis and Futuna': [],
#  'Samoa': ['Giant Clam Sanctuary',
#   'Lalomanu Beach',
#   'Tiapapata Art Centre',
#   'Sopoaga Falls',
#   'Palolo Deep Marine Reserve',
#   'Papaseea Sliding Rock',
#   'Fugalei Market',
#   'Apia Town Clock Tower',
#   'Museum of Samoa',
#   'Lefaga Beach',
#   'EFKS Museum',
#   'Salamumu Beach',
#   'Immaculate Conception of Mary Cathedral',
#   'Swimming with Turtles',
#   'Togitogiga Waterfall',
#   'Coastal Lava Cliff Walk',
#   'Papapapaitai Falls',
#   'To Sua Ocean Trench',
#   'Tafa Tafa Beach',
#   'Fuipisia Waterfall',
#   'Piula Cave Pool',
#   "Baha'i House of Worship, Tiapapata, Samoa",
#   'Samoa Cultural Village',
#   'Robert Louis Stevenson Museum',
#   'Old Apia Market',
#   "The Vanya Taule'alo Gallery",
#   'Alofaaga Blowholes',
#   'Samoa Culture Centre',
#   'Falefa Falls',
#   'Afu Aau Waterfall'],
#  'Yemen': ['Wadi Dirhur Canyon',
#   'Shajarat Al Ghareeb',
#   'Ayhaft Canyon National Park',
#   'Qalansiyah Beach',
#   'Al-Quahira Castle',
#   'Sira Castle',
#   'Arher Beach',
#   'Bab al-Yemen',
#   'Aden Mall',
#   'Alghareeb Tree',
#   'Dar al-Hajar',
#   'Socotra Island',
#   'Skand Peak',
#   'Diksam Plateau',
#   'Old City of Sanaa',
#   'Al Saleh Mosque',
#   'Shoab beach',
#   'Queen Arwa Mosque',
#   'Moschea Di Al Asharafya',
#   'Tawilah Tanks Crater',
#   'Mudhaffar Mosque',
#   'Aban Mosque',
#   'Al-Khair Mosque',
#   'Great Mosque',
#   'Al Janad Mosque',
#   'Aomak Beach',
#   'Delisha Beach',
#   "Great Mosque of Sana'a"],
#  'South Africa': ['Robberg Nature Reserve',
#   'Pilanesberg National Park',
#   'Durban Botanic Gardens',
#   'Spier Wine Farm',
#   'Apartheid Museum',
#   'Aerial Cableway Hartbeespoort',
#   'Table Mountain Aerial Cableway',
#   'Shamwari Private Game Reserve',
#   'Drakensberg Mountains',
#   'Franschhoek Motor Museum',
#   'Blyde River Canyon Nature Reserve',
#   'Gautrain',
#   'Victoria & Alfred Waterfront',
#   'Hennops Hiking Trail',
#   'Game drives at Phalaborwa Gate in Kruger National Park',
#   'Montecasino',
#   'uShaka Marine World',
#   'Seal Island',
#   "Lion's Head",
#   'Voortrekker Monument',
#   'St. Blaize Trail',
#   "Chapman's Peak Drive",
#   'Union Buildings',
#   'Hermanus Cliff Path',
#   'Waterford Estate',
#   'Knysna Heads',
#   'Kruger National Park',
#   'Boulders Beach Penguin Colony',
#   'Pretoria National Botanical Garden',
#   'The Cango Caves'],
#  'Zambia': ['Lusaka National Park',
#   'Chaminuka Game Reserve',
#   'Cathedral of The Holy Cross Lusaka',
#   'Wayiwayi Art Studio and Gallery',
#   '37D Gallery',
#   'Zambezi Eco Adventures',
#   'Victoria Falls (Mosi-oa-Tunya) National Park',
#   'Sunday Crafts Market',
#   'Eastpark Mall',
#   'Victoria Falls',
#   'Arcades Shopping Mall',
#   'Chilenje House',
#   'Royal Livingstone Express',
#   'Namwane Art Gallery',
#   'Pakati Sunday Market',
#   "Devil's Pool",
#   'PaZuri Place',
#   'Ride Zambezi Private Trails',
#   'Railway Museum',
#   'Victoria Falls',
#   'Lower Zambezi National Park',
#   'Livingstone Reptile Park',
#   'Munda Wanga Environmental Park',
#   'Zambia National Museum',
#   'Livingstone Museum',
#   'Kazungula Ferry',
#   'Gorge Swing',
#   'Kalimba Reptile Park',
#   'South Luangwa National Park',
#   'Railway & Gateway Jewish Museum'],
#  'Zimbabwe': ['Balancing Rocks',
#   'Prime Art Gallery',
#   'Mosi-oa-Tunya / Victoria Falls National Park',
#   'Kuimba Shiri Bird Sanctuary',
#   'Hwange National Park',
#   'Siduli Hide',
#   'Victoria Falls Snake Park',
#   'Mtarazi Falls',
#   'Thetford Game Reserve',
#   'Great Zimbabwe National Monument',
#   'Crocodile Park Victoria Falls',
#   'Victoria Falls',
#   'Lake Kariba',
#   'Gonarezhou National Park',
#   'Mukuvisi Woodlands',
#   'Lake Chivero Recreational Park',
#   'Wild Is Life Trust and ZEN',
#   'Victoria Falls Bridge',
#   'Ngoma Kurira',
#   'Matobo National Park',
#   "Elephant's Walk Shopping and Artist's Village",
#   'Raintree Venue',
#   'Lion and Cheetah Park',
#   'National Botanical Gardens',
#   'Kingfisher Park',
#   "World's View",
#   'The Shona Sculpture Gallery',
#   "Kumbirai Kako's Store",
#   'Haka Game Park',
#   'Twala Trust Animal Sanctuary']}

# %%
def top_places_to_visit(country):
    '''
        From a dictionary of attractions (defiend as {country name: attractions})
        returns TOP 10 places to visit. In case data for this country are note
        available returns 10 NAs.
    '''
    if attractions[country][0:10] != []:
        return attractions[country][0], attractions[country][1], attractions[country][2],attractions[country][3], attractions[country][4],attractions[country][5],attractions[country][6],attractions[country][7],attractions[country][8],attractions[country][9]
    else:
        return 'NA','NA','NA','NA','NA','NA','NA','NA','NA','NA'

# %%
top_places_to_visit('Czechia')
# Out:
# ('iQLANDIA',
#  'Prague Castle',
#  'Holy Trinity Column',
#  'Charles Bridge',
#  'Prague Zoo',
#  'Lesser Town',
#  'Villa Tugendhat',
#  'Lobkowicz Palace',
#  'Spilberk Castle',
#  'Konopiste Castle')

# %%
def location_map_function(country):
    '''
        Returns a world map where the given country is highlighted.
        As only data provided are the ones of the country - only the
        country is coloured in the output map.
    '''
    trace2 = go.Choropleth(locations= [country],z=[1],text = country,
                            autocolorscale=True, locationmode = 'country names',showscale= False)
    return {"data": [trace2],
            "layout": go.Layout(height=500,
            margin=go.layout.Margin(l=0,r=0,b=0,t=0,pad=4),
            geo={'showframe': False,'showcountries':True,'showcoastlines': True,'projection': {'type': "miller"}})}

# %%
def scatter(country,characteristic):
    '''
        Returns a scatter plot of the given characteristic
        over the period of 1990 and 2016. If data are not
        available on inqubu, returns and empty plot.
    '''
    data = getData(characteristic,country)
    years=[]
    char=[]
    if (data != {'type': 'error', 'msg': 'Invalid data argument.'}
       and data[0][characteristic] !=[]):
       #checking if data available, 2 possible cases of no data
        for i in data[0][characteristic]:
            years.append(i['year'])
            char.append(i['data'])
        title_graph =' '
    else:
        years = list(range(1990,2017))
        popul = [0]*27
        title_graph = 'DATA NOT AVAILABLE'
    return {
        'data': [go.Scatter(
                x=years,
                y=char,
                mode='lines+markers',
                marker={'size': 5,'opacity': 0.5,'line': {'width': 0.5, 'color': 'blue'}})],
        'layout': go.Layout(
                xaxis={'title': 'Years'},
                yaxis={'title': list(characteristics_dict.keys())[list(characteristics_dict.values()).index(characteristic)],},
                title = title_graph,
                margin={'l': 60, 'b': 30, 't': 30, 'r': 30},
                hovermode='closest')}

# %%
def world_map(characteristic,year):
    '''
        For a given characterictis and year returns world map.
        If data not availalble, returns grey map.
    '''
    df=pd.read_json(json.dumps(getDataWorld(characteristic,str(year)))) #loading the data from API
    if len(df) != 0 : #if there are some data:
        return {"data":[go.Choropleth(locations=df['countryName'],z=df[characteristic],text = df['countryName'],
                            autocolorscale=False, locationmode = 'country names',
                            colorscale = "YlGnBu", marker = {'line':{'color':'rgb(180,180,180)','width':0.5}},
                            colorbar={"thickness": 10,"len": 0.3,"x": 0.1,"y": 0.3,
                                    'title': {"text": 'White = NA', "side": "bottom"}})],
                "layout":go.Layout(height=500,
                        margin=go.layout.Margin(l=0,r=0,b=0,t=0,pad=4),
                        geo={'showframe': False,'showcountries':True,'showcoastlines': True,'projection': {'type': "miller"}})}
    else:# if no data available
        return {"data":[go.Choropleth(locations=list(countries.keys()),z=np.zeros(len(list(countries.keys()))),
                            autocolorscale=True, locationmode = 'country names',
                            colorbar={"thickness": 0.1,"len": 0.3,"x": 0.1,"y": 0.2,
                                    'title': {"text": characteristic, "side": "bottom"}})],
                "layout":go.Layout(height=500,
                        title = go.layout.Title(text = 'NO DATA. TRY DIFFERENT YEAR'),
                        margin=go.layout.Margin(l=0,r=0,b=0,t=30,pad=4),
                        geo={'showframe': False,'showcoastlines': True,'showcountries':True,'projection': {'type': "miller"}})}
